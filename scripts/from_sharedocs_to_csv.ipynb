# %% [markdown]
# # Retranscrire ses entretiens avec Whisper
#
# [Whisper](https://github.com/openai/whisper) est le nom donné par Open IA (Chat GPT) à son système de reconnaissance vocale multilingue. Dans ce tutoriel, nous montrons deux façon d'utiliser Whisper via les services Huma-Num.
#
# ShareDocs est un service de stockage et de partage mis à la disposition des communautés de recherche en sciences humaines et sociales par Huma-Num. Via ShareDocs, on a égalment accès à différents outils de traitement dont Whisper.
#
# ###  Quel est l'intérêt ?
#
# 1. on maîtrise la "destinée" de ses données : elles restent privées.
#
# 2. On bénéficie des capacité de calcul d'Huma-Num et on évite de cramer son ordinateur.
#
# 3. On a accès au modèle "with speaker" et à sept langue : allemand, anglais, français, espagnol, italien, portugais, russe.
#
# ### les inconvénients
#
# 1.  Il ne sera pas possible de "fine-tuner" les modèles
#
#
# ### Comment y accèder
#
# Une fois connecter à ShareDocs, on accède aux outils en allant dans le dossier "hnTools_watchFolder" (figure ci-dessous). Whisper se trouve dans le dossier "SpeechtoText". Quand on est dans le dossier "whisper", on retrouve quatre modèles : les modèles "tiny", "medium" et "large" que nous avons déjà vu plus haut, ainsi que le modèle "with speaker" qui permet, dans la mesure du possible, d'identifier les différents interlocuteurs. Ce qui peut-être pratique dans le cas d'une retranscription d'entretien.
#
#
# ![](../figures/Capture_ecran_2026-01-12_11-25-22_sharedocs.png)
#
# Il suffit ensuite de choisir le modèle que l'on souhaite utiliser et d'y déposer le ou les fichiers audios que l'on veut retranscrire. Dans le cadre de l'atelier, je vous propose d'utiliser les modèles "medium" et "with_speaker", puis vous sélectionner la langue correspondant à votre entretien. On pourra ainsi comparer les résultats. Dans mon cas, le modèle "with_speaker" a produit de meilleurs résultats.
#
# ![](../figures/Capture_ecran_2026-01-12_12-37-20_versement_fichier.png)
#
#
# Selon le nombre et la taille des fichiers, le temps de retranscription sera plus ou moins long. La retranscription des deux fichiers audios (2h d'entretien chacun) pour l'atelier à pris une heure environ. Huma-Num vous prévient de la fin de la retranscription par un e-mail. Le résultat prend la forme d'un dossier contenant la retranscription enregistrée dans différents formats : txt, tsv (tabular separator value), srt et vtt.
#
# Ces fichiers peuvent être ouverts avec un logiciel de traitement de texte, un tableur (excel, libreoffice).
#
# ## Ouvrir les fichiers ".srt"
#
# Pour commencer, nous allons ouvrir, lire et traiter les "fichiers ".srt" (format de fichier utilisé pour les sous-titres sur youtube par exemple).

# %%
gb_trasncript = "../records/grazia_borrini_07-06-18_with_speaker.srt" # comme on va utiliser plusieur fois le fichier, on enregistre sa localisation dans une variable

# %%
with open(gb_trasncript, 'r', encoding='utf-8-sig') as srt : #signifie qu'on ouvre le fichier et on le conserve dans l'objet srt
    i = 0
    for line in srt:
        i+=1
        if i <= 40:
            print(line)
        else:
            pass
# Out:
# 1
#
# 00:00:01,820 --> 00:00:09,259
#
# Speaker 1: Je suis arrivé en post-doctorat au Muséum National d'Historie Naturelle l'année dernière, en septembre.
#
#
#
# 2
#
# 00:00:09,299 --> 00:00:19,930
#
# Speaker 1: C'est un projet porté par à la fois Stéphanie Duvaille et les écologues qui ont mis au point ce qu'on appelle les sciences participatives ou en anglais les citizen science.
#
#
#
# 3
#
# 00:00:20,441 --> 00:00:22,143
#
# Speaker 0: Oh, Citizen Science, ok.
#
#
#
# 4
#
# 00:00:22,183 --> 00:00:32,453
#
# Speaker 1: Avec l'idée de faire participer le public à la récolte de données, etc.
#
#
#
# 5
#
# 00:00:32,493 --> 00:00:35,517
#
# Speaker 0: Peut-être direction de recherche aussi, n'est-ce pas?
#
#
#
# 6
#
# 00:00:35,517 --> 00:00:35,597
#
# Speaker 1: ?
#
#
#
# 7
#
# 00:00:35,597 --> 00:00:43,638
#
# Speaker 1: Et puis Stéphanie Duval et son labo qui est plutôt... qu'on pourrait appeler recherche participative.
#
#
#
# 8
#
# 00:00:43,658 --> 00:00:52,661
#
# Speaker 1: Là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes.
#
#
#
# 9
#
# 00:00:53,782 --> 00:01:14,258
#
# Speaker 1: Et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de participation, de pratique participative dans la production de connaissances.
#
#
#
# 10
#
# 00:01:14,278 --> 00:01:24,184
#
# Speaker 1: Donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc.

# %% [markdown]
# ### Exercices
#
# 1. **Dans la cellule ci-dessous, entre les guillemets, collez l'adresse du fichier correspondant à la retranscription de l'entretien de Marie Roué**
#
# 2. **Ensuite, créer une nouvelle cellule au format "code" dans laquelle vous reproduirez les lignes de code pour ouvrir le fichier et lire les 10 premières lignes.**

# %%
mr_transcript = "../records/Marie_Roue_29-03-18_with_speaker.srt" # comme on va utiliser plusieur fois le fichier, on enregistre sa localisation dans une variable

# %%
#Ici reproduire les lignes de code permettant d'ouvrir et de lire un fichier:
with open(mr_transcript, 'r', encoding='utf-8-sig') as srt : 
    i = 0
    for line in srt:
        i+=1
        if i <= 40:
            print(line)
        else:
            pass
# Out:
# 1
#
# 00:00:05,980 --> 00:00:15,620
#
# Speaker 1: Donc je vais vous présenter un peu, redire un peu pourquoi on se rencontre et puis on intègre pas l'entretien.
#
#
#
# 2
#
# 00:00:15,660 --> 00:00:24,802
#
# Speaker 1: Donc moi je suis Aymeric et j'ai été recruté en post-doctorat pour travailler sur la question des observatoires participatifs.
#
#
#
# 3
#
# 00:00:24,842 --> 00:00:25,542
#
# Speaker 0: Et vous êtes.
#
#
#
# 4
#
# 00:00:25,582 --> 00:00:26,823
#
# Speaker 0: quoi comme formation de doctorat ?
#
#
#
# 5
#
# 00:00:26,823 --> 00:00:27,943
#
# Speaker 1: Moi je suis sociologue.
#
#
#
# 6
#
# 00:00:27,983 --> 00:00:29,843
#
# Speaker 1: Je suis formé en sociologie.
#
#
#
# 7
#
# 00:00:29,863 --> 00:00:30,023
#
# Speaker 1: D'accord.
#
#
#
# 8
#
# 00:00:30,043 --> 00:00:31,664
#
# Speaker 1: J'ai fait une thèse en sociologie.
#
#
#
# 9
#
# 00:00:31,724 --> 00:00:33,666
#
# Speaker 0: En sociologie sur l'environnement ?
#
#
#
# 10
#
# 00:00:33,666 --> 00:00:39,290
#
# Speaker 1: Oui, j'ai travaillé sur les conflits environnementaux dans lesquels s'engageaient les riverains.

# %% [markdown]
# ### Chargement des modules

# %%
import time
import csv
import datetime

# %% [markdown]
# ## Mise en forme et sauvegarde
#
# ### Convertir un fichier srt au format csv
#
# Pour le moment, lorsqu'on utilise le modèle "with_speaker" sur Sharedocs, les résultats sont enregistrés aux formats "txt" et "srt", mais pas au format "csv" (comma-separated value). Or ce dernier format peut s'avérer plus pratique pour analyser les entretiens dès lors que l'on veut faire quelques analyses quantitatives.
#
# Ci-dessous, vous trouverez une fonction (appelée "srt_to_csv") permettant de créer un fichier csv à partir du fichier "srt".

# %%
#(inspiration Yacine Chitour)
def convertir(seconds):
    h = int(seconds // 3600)
    m = int((seconds % 3600) // 60)
    s = int(seconds % 60)
    ms = int((seconds - int(seconds)) * 1000)
    return f"{h:02d}:{m:02d}:{s:02d},{ms}"

def convert_to_second(str_time):
    h = int(str_time.split(":")[0])*3600
    m = int(str_time.split(":")[1])*60
    s= int(str_time.split(":")[2].split(",")[0])
    ms = float("0."+str_time.split(',')[-1])
    return h+m+s+ms

# %%
h = convertir(10.64)
print(h, convert_to_second(h))
# Out:
# 00:00:10,640 10.64

# %% [markdown]
# ### Exercice
#
# Ajoutez une cellule au format "code" sous celle-ci et ouvrez le fichier ".srt" correspondant à l'entretien avec Marie Roue.

# %%
def srt_to_csv(path_of_file):
    with open(path_of_file.replace('.srt', '.csv'), 'w', newline='') as csvfile:
        fieldnames = ['id', 'start', 'end','speaker', 'text','start_in_ms','end_in_ms']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        with open(path_of_file, 'r', encoding='utf-8-sig') as srt :
            i = 0
            dict_segment = {}
            list_segment = []
            for line in srt:
                i+=1
                #print("ligne : ", i)
                #print(line)
                if i ==4:
                    writer.writerow({'id': dict_segment['id'],
                                     'start': dict_segment['start'],
                                     'end': dict_segment['end'],
                                     'speaker': dict_segment['speaker'],
                                     'text':dict_segment['text'],
                                     'start_in_ms':dict_segment['start_in_ms'],
                                     'end_in_ms':dict_segment['end_in_ms']})
                    list_segment.append(dict_segment)
                    dict_segment =  {}
                    i = 0
                elif i == 1:
                    dict_segment["id"] = line.strip()
                elif i == 2:
                    dict_segment["start"] = line.split(" --> ")[0].strip()
                    dict_segment["start_in_ms"] = convert_to_second(dict_segment["start"])
                    dict_segment["end"] = line.split(" --> ")[1].strip()
                    dict_segment["end_in_ms"] = convert_to_second(dict_segment["end"])
                elif i == 3 :
                    dict_segment["speaker"] = line.split(": ")[0]
                    dict_segment["text"] = line.split(": ")[1].strip()

# %%
srt_to_csv("../records/grazia_borrini_07-06-18.srt")

# %% [markdown]
# **Fin de la première partie**
