# %% [markdown]
# # Réaliser quelques traitements avec Python
#
# Dans ce notebook, on explore différents "outils" permettant de faire des traitements simples comme "pseudonymiser" les entretiens, compter les occurrences d'un mot ou faire ressortir les termes spécifiques d'un entretien.
#
# Certains de ces traitements peuvent être réalisés avec les modules de base de Python, d'autres font appel à des modules spécialisés dans le traitement automatique des langues comme les modules `Spacy` ou `Scikit Learn`.

# %%
# !pip install pypandoc
# Out:
# Requirement already satisfied: pypandoc in /opt/python/lib/python3.13/site-packages (1.16.2)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
### import re # Module pour utiliser les "regex", i.e. les expressions régulières

import pandas as pd # module pour manipuler des "dataframes". 
import csv # Outil pour lire et écrire des fichiers csv
import numpy as nmp

import pypandoc

import fileinput

# %% [markdown]
# ## Chargement des données
#
# On ouvre les fichiers csv contenant les retranscriptions avec `pandas`. Pour cela nous avons besoin de connaitre l'adress (ou chemin) du fichier et d'utiliser la fonction pd.read_csv(adresse du fichier, sep =","). L'argument "sep" correspond au séparateur utiliser pour marquer les colonnes.

# %%
gb_transcript = "../records/grazia_borrini_07-06-18.csv" # Adresse du fichier csv
gb = pd.read_csv(gb_transcript, sep=",")

# %% [markdown]
# **Exercice**
#
# Ouvrez le fichier "Marie_Roue_29-03-18.csv" avec pandas. Vous utiliserez "mr" (pour Marie Roué) pour nommer l'objet contenant le dataframe (c'est-à-dire les données du fichier csv).

# %%
mr_transcript = "../records/Marie_Roue_29-03-18.csv"
mr = pd.read_csv(mr_transcript, sep=",")

# %% [markdown]
# # Regrouper les segments en blocs
#
# Whisper découpe l'entretient en segment de plus ou moins 10 secondes. Pour lire l'entretien, il peut toutefois être plus facile de regrouper les segments liés à une même question par exemple. Le regroupement facilitera également le calcul du "TF-IDF" que l'on verra plus loin.

# %%
def get_bloc(data, column, new_dataframe = False) : #fonction pour regrouper les segments d'un même bloc (prise de parole d'un locuteur)
    """Groupe les segments d'une retranscription whisper en bloc.

    ------
    data : le dataframe contenant la retranscription. Le dataframe doit avoir à minima une colonne "segment"
    column : la colonne à partir de laquelle  le regroupement est effectué.
    new_dataframe : Si faux (argument par défaut), la fonction crée une nouvelle colonne au dataframe (dans lequel une ligne est égal à un segment). Si vrai, la fonction retourne un nouveau dataframe dans lequel une ligne est égal un bloc
    """
    
    dict_bloc_id = {}
    for n, speaker in enumerate(data[column]):
        if n == 0:
            bloc_id = n
        else :
            if speaker == data[column].iloc[n-1]:
                bloc_id = int(dict_bloc_id[n-1].replace("bloc_",""))
            else:
                bloc_id = int(dict_bloc_id[n-1].replace("bloc_",""))+1
        dict_bloc_id[n] = "bloc_"+str(bloc_id)
    data["bloc_id"] = data.index.map(dict_bloc_id.get)
    data["bloc_text"] = data.groupby(['bloc_id'])['text'].transform(lambda x : ' '.join(x))
    data["start_bloc"] = data.groupby(['bloc_id'])['start'].transform("min")
    data["end_bloc"] = data.groupby(['bloc_id'])['end'].transform("min")
    data["start_bloc_ms"] = data.groupby(['bloc_id'])['start_in_ms'].transform("min")
    data["end_bloc_ms"] = data.groupby(['bloc_id'])['end_in_ms'].transform("min")
    if new_dataframe==True:
        data = data.drop(columns=["text", "id","start", "end", "start_in_ms", "end_in_ms"]).drop_duplicates()
    return dict_bloc_id, data


def write_bloc_in_list(data, column_of_text = "text", segment_tag=False, segment_id=None):
    """
    Ecrit les blocs obtenu avec la fonction "get_bloc" dans une liste.

    ------
    data: le dataframe contenant la retranscription avec les segments regroupés par bloc.
    column_of_text : le nom de la colonne contenant le text.
    segment_tag : Boolean (Faux par défaut). Si vrai et que le dataframe contient une colonne segment, la fonction ajout un tag sous la forme "<seg_id>segment</seg_id>" pour marquer le début et la fin de chaque segment d'un même bloc.
    segment_id : non de la colonne contenant les idenfitifiants des segments

    Retourne une liste des blocs (utile pour le calcul du tf-idf ensuite)
    """
    
    list_bloc_text = []
    #dict_speaker = {}
    for n, b in enumerate(data.bloc_id.unique()):
        data_tmp = data.loc[data.bloc_id == b]
        if segment_tag == True:
            new_text = ""
            try:
                for m, seg in enumerate(data_tmp[segment_id]):
                    new_text = new_text + "<" + seg + ">" + data_tmp[column_of_text].iloc[m]  + "</" + seg + ">" #décommenter la ligne ci-dessous si on souhaite mettre des balises indiquant le début et la fin des segments que l'on concatène
            except:
                raise
        else:
            new_text = data_tmp[column_of_text].iloc[0] 
        list_bloc_text.append({"bloc_id":b, "speaker": data_tmp.speaker.unique()[0], "bloc_text" : new_text, "start_bloc": data_tmp.start_bloc.iloc[0], "end_bloc": data_tmp.end_bloc.iloc[0]})
    return list_bloc_text

# %%
dict_bloc_id, gb1 = get_bloc(data=gb, column="speaker", new_dataframe=False)
gb1
# Out:
#           id         start           end    speaker  \
# 0      seg_1  00:00:01,820  00:00:09,259  Speaker 1
# 1      seg_2  00:00:09,299  00:00:19,930  Speaker 1
# 2      seg_3  00:00:20,441  00:00:22,143  Speaker 0
# 3      seg_4  00:00:22,183  00:00:32,453  Speaker 1
# 4      seg_5  00:00:32,493  00:00:35,517  Speaker 0
# ..       ...           ...           ...        ...
# 929  seg_930  02:13:20,896  02:13:24,978  Speaker 0
# 930  seg_931  02:13:25,018  02:13:48,798  Speaker 0
# 931  seg_932  02:13:48,818  02:13:49,499  Speaker 0
# 932  seg_933  02:13:59,889  02:14:03,773  Speaker 1
# 933  seg_934  02:14:03,793  02:14:04,574  Speaker 1
#
#                                                   text  start_in_ms  \
# 0    Je suis arrivé en post-doctorat au Muséum Nati...        1.820
# 1    C'est un projet porté par à la fois Stéphanie ...        9.299
# 2                             Oh, Citizen Science, ok.       20.441
# 3    Avec l'idée de faire participer le public à la...       22.183
# 4    Peut-être direction de recherche aussi, n'est-...       32.493
# ..                                                 ...          ...
# 929               Bon, il y a plus de responsabilités.     8000.896
# 930  C'est un peu... Évidemment, il y a plus de res...     8005.018
# 931                                  Ça fiche de tout.     8028.818
# 932                                Bon, on va essayer.     8039.889
# 933                          Merci en tout cas pour...     8043.793
#
#      end_in_ms   bloc_id                                          bloc_text  \
# 0        9.259    bloc_0  Je suis arrivé en post-doctorat au Muséum Nati...
# 1       19.930    bloc_0  Je suis arrivé en post-doctorat au Muséum Nati...
# 2       22.143    bloc_1                           Oh, Citizen Science, ok.
# 3       32.453    bloc_2  Avec l'idée de faire participer le public à la...
# 4       35.517    bloc_3  Peut-être direction de recherche aussi, n'est-...
# ..         ...       ...                                                ...
# 929   8004.978  bloc_109  La France est particulière, ce sens, n'est-ce ...
# 930   8028.798  bloc_109  La France est particulière, ce sens, n'est-ce ...
# 931   8029.499  bloc_109  La France est particulière, ce sens, n'est-ce ...
# 932   8043.773  bloc_110      Bon, on va essayer. Merci en tout cas pour...
# 933   8044.574  bloc_110      Bon, on va essayer. Merci en tout cas pour...
#
#        start_bloc      end_bloc  start_bloc_ms  end_bloc_ms
# 0    00:00:01,820  00:00:09,259          1.820        9.259
# 1    00:00:01,820  00:00:09,259          1.820        9.259
# 2    00:00:20,441  00:00:22,143         20.441       22.143
# 3    00:00:22,183  00:00:32,453         22.183       32.453
# 4    00:00:32,493  00:00:35,517         32.493       35.517
# ..            ...           ...            ...          ...
# 929  02:11:45,664  02:11:48,406       7905.664     7908.406
# 930  02:11:45,664  02:11:48,406       7905.664     7908.406
# 931  02:11:45,664  02:11:48,406       7905.664     7908.406
# 932  02:13:59,889  02:14:03,773       8039.889     8043.773
# 933  02:13:59,889  02:14:03,773       8039.889     8043.773
#
# [934 rows x 13 columns]

# %%
write_bloc_in_list(data=gb1, column_of_text = "bloc_text", segment_tag=False, segment_id="id")
# Out:
# [{'bloc_id': 'bloc_0',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Je suis arrivé en post-doctorat au Muséum National d'Historie Naturelle l'année dernière, en septembre. C'est un projet porté par à la fois Stéphanie Duvaille et les écologues qui ont mis au point ce qu'on appelle les sciences participatives ou en anglais les citizen science.",
#   'start_bloc': '00:00:01,820',
#   'end_bloc': '00:00:09,259'},
#  {'bloc_id': 'bloc_1',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Oh, Citizen Science, ok.',
#   'start_bloc': '00:00:20,441',
#   'end_bloc': '00:00:22,143'},
#  {'bloc_id': 'bloc_2',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Avec l'idée de faire participer le public à la récolte de données, etc.",
#   'start_bloc': '00:00:22,183',
#   'end_bloc': '00:00:32,453'},
#  {'bloc_id': 'bloc_3',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Peut-être direction de recherche aussi, n'est-ce pas?",
#   'start_bloc': '00:00:32,493',
#   'end_bloc': '00:00:35,517'},
#  {'bloc_id': 'bloc_4',
#   'speaker': 'Speaker 1',
#   'bloc_text': "? Et puis Stéphanie Duval et son labo qui est plutôt... qu'on pourrait appeler recherche participative. Là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes. Et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de participation, de pratique participative dans la production de connaissances. Donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc. Dans ce cadre, j'aimerais qu'on revienne un peu à la fois sur votre parcours et comment vous avez discuté cette idée de participation, comment ça s'intègre dans votre trajectoire, etc.",
#   'start_bloc': '00:00:35,517',
#   'end_bloc': '00:00:35,597'},
#  {'bloc_id': 'bloc_5',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Oui, très volontiers. Mais en général, j'aimerais bien savoir où vous allez avec ça. C'est quoi vraiment le but ? La raison de l'intérêt pour la participation, ça vient de quel esprit, de quel rêve, de quelle direction de travail ? C'est une histoire... Plutôt, disons, car il y a un travail possible, ou bien car c'est une histoire personnelle de choix, je veux faire quelque chose avec ma vie, ou bien c'est une histoire que je ne comprends pas, ce côté des choses, ça vient d'où ?",
#   'start_bloc': '00:01:37,553',
#   'end_bloc': '00:01:40,375'},
#  {'bloc_id': 'bloc_6',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Alors moi j'ai trouvé un intérêt au départ en tant qu'étudiant en sociologie pour les questions de la mobilisation collective et je me suis intéressé à les mouvements de riverains ou d'habitants qui se mobilisent contre des pollutions chimiques, etc. et comprendre comment ils arrivent à faire remonter un problème...",
#   'start_bloc': '00:02:31,840',
#   'end_bloc': '00:02:55,734'},
#  {'bloc_id': 'bloc_7',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Ensemble. Voilà. Et c'est dans ce cadre-là que...",
#   'start_bloc': '00:03:01,299',
#   'end_bloc': '00:03:01,799'},
#  {'bloc_id': 'bloc_8',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Je m'intéresse à cette interaction entre ce qu'on pourrait appeler des gens qu'on qualifierait de non-scientifiques, entre guillemets, avec des gens...",
#   'start_bloc': '00:03:07,016',
#   'end_bloc': '00:03:17,263'},
#  {'bloc_id': 'bloc_9',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Des gens normaux.',
#   'start_bloc': '00:03:17,283',
#   'end_bloc': '00:03:18,324'},
#  {'bloc_id': 'bloc_10',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Voilà.',
#   'start_bloc': '00:03:18,344',
#   'end_bloc': '00:03:18,784'},
#  {'bloc_id': 'bloc_11',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Des gens...',
#   'start_bloc': '00:03:18,824',
#   'end_bloc': '00:03:20,545'},
#  {'bloc_id': 'bloc_12',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Et après, effectivement, ce projet-là, c'est plutôt un travail en tant que tel. Pour... Après, c'est un intérêt aussi de comprendre comment ces nouvelles... Au fur et à mesure de mon travail, ce qui m'intéresse, c'est de comprendre les nouvelles... Qu'est-ce que ça fait comme... Qu'est-ce que ça définit comme nouvelle norme, etc. Donc c'est peut-être plus un... Après, je ne sais pas trop encore ce que je vais en faire.",
#   'start_bloc': '00:03:20,645',
#   'end_bloc': '00:03:28,070'},
#  {'bloc_id': 'bloc_13',
#   'speaker': 'Speaker 0',
#   'bloc_text': "C'est ouvert. C'est bien que c'est ouvert. Mais le sujet est passionnant quand même, car ça peut nous sauver la vie, ça peut nous embêter beaucoup. Tout ça, c'est les réunions du condominium, on déteste tout ça. Et en même temps, sans la capacité d'être ensemble, de participer, on aime... On est lâchés dans un monde de trompes, et voilà. Oui, c'est intéressant. Alors, vous aimeriez partir, mettez-vous confortable, s'il vous plaît. Il faut vraiment se mettre confortable, bouger les coussins. Là, c'est une très vieille histoire, il n'y a pas de problème, c'est ce que vous voulez faire. Qu'est-ce que vous voulez savoir? des racines pour arriver où ? C'est ça que j'aimerais... Pour avoir un peu d'outils, vous aimeriez que je vous donne un peu d'expérience de ce que j'ai vu, de positif ou négatif. Je peux vous conter beaucoup d'histoires, mais là, ça serait bien de vous être utile. Oui.",
#   'start_bloc': '00:03:53,763',
#   'end_bloc': '00:03:55,604'},
#  {'bloc_id': 'bloc_14',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Moi, je suis parti, en fait, du consortium ICA. Et avant...',
#   'start_bloc': '00:05:14,241',
#   'end_bloc': '00:05:20,945'},
#  {'bloc_id': 'bloc_15',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'À Pâques, en français.',
#   'start_bloc': '00:05:22,706',
#   'end_bloc': '00:05:25,847'},
#  {'bloc_id': 'bloc_16',
#   'speaker': 'Speaker 1',
#   'bloc_text': "À Pâques, oui. Et avant, du coup, il y a... J'aimerais comprendre ce que fait ICA...",
#   'start_bloc': '00:05:25,867',
#   'end_bloc': '00:05:26,288'},
#  {'bloc_id': 'bloc_17',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Les consortiums, oui.',
#   'start_bloc': '00:05:34,332',
#   'end_bloc': '00:05:36,853'},
#  {'bloc_id': 'bloc_18',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Et justement, comment on en arrive à faire... à la fois ça et en même temps, parce que je regarde beaucoup d'acteurs et tous les acteurs essayent de se dire différents des autres. Justement, quelle est votre position sur cette... Par exemple, j'ai vu récemment, je ne sais pas si vous connaissez Marie Roué, qui est la femme de Douglas Nakashima, etc. Quel est, par exemple, le lien avec les savoirs autochtones, etc.",
#   'start_bloc': '00:05:36,933',
#   'end_bloc': '00:05:52,396'},
#  {'bloc_id': 'bloc_19',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Non, je ne connais pas tellement ce travail. Oui, il y a beaucoup de choses qui s'entremêlent, qui se superposent. Il y a des efforts, il y a un monde de problèmes, etc. Alors, bon... Vous aimeriez faire quelque chose avec cette participation, n'est-ce pas? ? Arriver à un point de changement, de prise, pas seulement de conscience, mais de prise de pouvoir des citoyens. Oui, oui, c'est comprendre comment...",
#   'start_bloc': '00:06:10,978',
#   'end_bloc': '00:06:13,079'},
#  {'bloc_id': 'bloc_20',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Je le vois comme une critique, tous ces mouvements comme une critique des sciences. La foi des sciences et de leur relation aux politiques. Et donc, comprendre comment ça intervient. Quelles sont les différentes voies de cette critique ?',
#   'start_bloc': '00:06:49,804',
#   'end_bloc': '00:06:57,767'},
#  {'bloc_id': 'bloc_21',
#   'speaker': 'Speaker 0',
#   'start_bloc': '00:07:15,325',
#   'end_bloc': '00:07:24,143'},
#  {'bloc_id': 'bloc_22',
#   'speaker': 'Speaker 1',
#   'bloc_text': "C'était pas apprécié par qui ?",
#   'start_bloc': '00:17:28,863',
#   'end_bloc': '00:17:31,437'},
#  {'bloc_id': 'bloc_23',
#   'speaker': 'Speaker 0',
#   'bloc_text': "par ces médecins qui étaient là, qui d'une certaine façon voulaient faire du nouveau, mais en même temps voulaient faire du nouveau santé primaire. Ça veut dire, oui, la participation de la communauté dans les soins de santé, mais quand même, toujours les soins, c'est les médecins qui décident.",
#   'start_bloc': '00:17:31,437',
#   'end_bloc': '00:17:43,368'},
#  {'bloc_id': 'bloc_24',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Merci.',
#   'start_bloc': '00:17:53,417',
#   'end_bloc': '00:17:53,657'},
#  {'bloc_id': 'bloc_25',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Et ce n'est pas seulement les tertiaires ou les secondaires, mais c'est la santé primaire. Ça veut dire, oui, il y a l'eau potable, il y a la prise en compte de l'environnement, mais c'était encore du point de vue santé. Et ce que j'ai découvert au fur et à mesure que j'étais là, que j'étais en train de penser, car je dois revenir un peu en arrière, la raison pour laquelle on m'a demandé de venir... de rentrer en Italie quand j'étais en Californie, était car à ce moment-là j'écrivais dans un magasin qui s'appelait, probablement il est mort depuis mille ans, s'appelait « Science Experience » et c'était « c'est » en italien, que ça signifie « if » en anglais, « si » en français. C'est un peu une histoire dubitative d'analyse de science, du rôle de science dans la société, etc. Et j'avais écrit une histoire sur les racines du problème de la faim. Et la faim, c'est la façon la plus éclatante de ce qu'on a quand on a un « failure » du point de vue social et du point de vue humain. Et environnemental, évidemment. Alors je m'étais pris vraiment à ce problème de la faim car je l'avais à un certain moment voulu expérimenter moi-même. J'avais fait une journée de jeûne que... Ça m'avait bouleversée. Je savais qu'il y a beaucoup de gens qui souffrent pour ça dans le monde, mais je n'imaginais pas que c'était tellement terrible. Il y a un écrivain du Nord, je ne me rappelle plus son nom, qui a écrit un livre qui s'appelle Hunger, que j'avais lu. Encore une fois, c'était vraiment bouleversant, etc. Car c'est vraiment la chose primordiale. On est réduit à un estomac, on pense à rien d'autre que ce que je dois manger pour vivre. Et ça, c'est une façon de mourir, d'une certaine façon, de mourir en tant que personne complète, multiple, tout ça. Bon, alors je reviens sur ça. J'avais écrit ça et on m'avait identifié à cause de cet article. On m'avait demandé si je voulais venir en Italie pour mettre en place cette nouvelle école qui était en train d'être mise en place à l'Institut National de Santé à Rome. Et pour moi, ça a été très intéressant, car je me suis dit, je m'en fiche de l'Université de Berkeley, je vais partir voir les choses sur le terrain, faire quelque chose vraiment de sérieux, et je suis partie, j'ai tout laissé, et je suis arrivée en Italie. Mais finalement, c'était un groupe de médecins qui était là, et moi j'ai joué un rôle assez... particuliers, car moi je n'étais pas sociologue, pas du tout, et j'ai une cert
choc de tout. Je venais de l'Italie, je venais de commencer un nouveau travail et je perdais la personne que j'aimais énormément. Et alors là, c'était bon. Je me suis jetée sur le travail. C'est la seule chose que je pouvais imaginer faire. J'ai travaillé vraiment un peu comme une folle, beaucoup, beaucoup, pendant plusieurs années. Et ce travail, j'ai fermé l'institution à minuit, chaque nuit. C'était à ce niveau-là de bêtise. Mais ça m'a aidée à comprendre beaucoup de choses, car j'ai travaillé beaucoup, j'ai lu beaucoup, j'ai étudié, je suis partie sur le terrain, j'ai connu énormément de l'huissienne, ce que je n'avais pas compris. C'était une opportunité énorme. Moi, maintenant, dans ma vie, je travaillais en... travailler sérieusement à 70 pays. C'est quelque chose qui ne passe pas tous les moments à n'importe qui. Alors c'était la possibilité d'aller sur le terrain, de voir des choses, de faire en sorte que les gens aient une chance.",
#   'start_bloc': '00:29:37,314',
#   'end_bloc': '00:29:38,574'},
#  {'bloc_id': 'bloc_28',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'La question du terrain est importante.',
#   'start_bloc': '00:33:37,876',
#   'end_bloc': '00:33:40,457'},
#  {'bloc_id': 'bloc_29',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Oh oui, énormément. Et c'est vrai que je n'ai pas la... par exemple, la profondeur d'un terrain spécifique comme Stéphanie ou Olivier peuvent avoir. Ils ont passé sept ans dans le même endroit. Ils connaissent le matin, le soir, le mardi, l'avril, le mai et le juillet. Mais pour moi, ça a été un vol d'oiseaux un peu différent. Mais quand même, je pense qu'avec la diversité de... de méthodologie, de vie que j'ai eu, la chance de connaître plusieurs langues et tout ça, j'avais une certaine facilité à comprendre les choses. Alors, j'arrivais, je voyais, je parlais en détail avec les gens et je pouvais assimiler beaucoup de choses. Je le dis sans fausse modestie, mais je pense que j'ai j'ai compris quelque chose en plus que que ça serait été possible si j'étais tout le temps dans un endroit dans lequel tu es peut-être confronté à une problématique mais une seule problématique. et par contre là on s'ouvre un peu la tête. oui et en plus avec ce système de référence de gens qui qui étaient là car ils étaient motivés par la beauté des animaux, on fait la conservation, des personnes très intéressantes, très valables, mais en même temps, qui n'avaient pas le même type de problématique que j'avais. Et voilà, ça m'a donné beaucoup d'expériences, d'épaisseur sur ça et j'ai, d'une certaine façon, je trouve que j'ai appris beaucoup de ce que les gens m'ont enseigné sur le terrain. jusqu'au moment dans lequel on a généré un mouvement politique à l'intérieur de l'UICN. C'était un mouvement pour ce qu'on appelait à ce moment-là le Collaborative Management. Alors la gestion, maintenant j'aimerais même faire un peu de définition de ce que c'est. dites en très peu de mots ce qu'on fait sur le terrain ce qu'on fait. mais aujourd'hui on comprend gouvernance. qui décide ce qu'on fait sur le terrain comment on le décide et est-ce qu'on va vraiment mettre en exécution ce qu'on a décidé ou pas?",
#   'start_bloc': '00:33:40,517',
#   'end_bloc': '00:33:42,097'},
#  {'bloc_id': 'bloc_30',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'on se connait.',
#   'start_bloc': '00:36:35,538',
#   'end_bloc': '00:36:36,779'},
#  {'bloc_id': 'bloc_31',
#   'speaker': 'Speaker 0',
#   'bloc_text': "C'est pas confortable d'être ici. Attends. Moi, j'ai passé beaucoup d'années... Beaucoup d'années sur ce sofa-là, en train d'écrire. Tu vas mettre les pieds là. C'est plus sympa. Pour toi. Je vais... Car autrement, on est un peu mal. Ça te dit ?",
#   'start_bloc': '00:36:44,780',
#   'end_bloc': '00:36:47,783'},
#  {'bloc_id': 'bloc_32',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Oui. Ce que je voulais dire, c'est que... Et on a confondu management avec décision dans des bureaux ?",
#   'start_bloc': '00:37:25,904',
#   'end_bloc': '00:37:26,724'},
#  {'bloc_id': 'bloc_33',
#   'speaker': 'Speaker 0',
#   'bloc_text': "À ce moment-là, il y avait seulement un mot, et c'était gestion. Et avec gestion, on voulait dire ce qu'aujourd'hui on dit beaucoup mieux, et je pense avoir contribué un tout petit peu à ça, à la distinction entre gestion et gouvernance. Car Et je dis une chose que je pense a beaucoup de significat si je dis que c'était quelque chose de très convenable pour les gestionnaires, car on ne distinguait pas. Et ce qui est relatif à, par exemple, si je veux que cet arbre grandisse beaucoup, je dois couper les rames d'un côté à l'autre. Ça c'est la gestion. Mais... Qui décide si l'arbre doit monter en hauteur ou en largeur, ou ici et là ? C'est de la gouvernance. Mais on mettait tout cela ensemble. On ne faisait pas la distinction entre les deux. Et surtout, on ne se demandait pas, mais c'est qui qui a le droit de décider ? C'était comme si tout était une question de gestion, et la gestion est une question technique. c'est à dire les techniciens ont le pouvoir de gouverner et gérer et ce n'est pas ça du tout. mais à l'intérieur d'une organisation qui est l'union mondiale pour la conservation de la nature nous les gestionnaires les techniciens les biologistes nous avons la connaissance et nous avons la gestion. Et la gestion, nous ne faisons pas cette distinction entre la gouvernance et la gestion. Nous ne demandons jamais qui a le droit de décider. Et c'était ça qu'on trouvait très bien sur les les situations de terrain, des aires protégées, du fait d'avoir créé tellement d'injustices, vraiment des délits de... Comment on dit ? victimes de non-respect des droits humains partout dans le monde. Ce n'était même pas de dire je ne veux pas respecter les droits. Mais non, c'est moi la personne qui a bien compris ce qu'il faut faire pour la conservation. qui a le droit de voir, de mettre en place ces initiatives. Et ce n'était pas... Ah, ça, c'est les écoliers qui, ce matin à 9 heures, ils sont passés, ils sont allés au Mont Pelerin, ils reviennent en arrière maintenant. Tous les jours, ce jour-là, il y a des écoles qui viennent. C'est pour dire que moi, j'ai commencé à ouvrir cette boîte. Et je l'ai fait avec beaucoup de passion, car comme je t'ai dit, je venais de perdre mon mari et j'avais besoin de me jeter sur quelque chose de fort. Et là, j'ai trouvé aussi d'autres personnes que j'ai commencé vraiment à tisser des liens, des relations professionnelles, d'amitié. qui se maintient à travers le temps, et ça nous est passé des histoires similaires. Je ne sais pas si tu as une copie de Sharing Power, tu l'as vu quelque part ? Bon, là, la personne avec laquelle je travaillais le plus sur ça s'appelle Michel Pambert, Et Michel et moi, nous avons eu une relation absolument très similaire. Premièrement, nous sommes nés le même jour, le même mois. Nous nous sentons vraiment comme si nous étions des jumeaux. Il est un peu plus jeune que moi. Mais lui,
du terrain, notamment au bassin du Congo. Je venais d'obtenir, le jour qui m'envierait, je venais de recevoir ce contrat pour un travail de plusieurs années au bassin du Congo. Et c'était sur la congestion. Et les bailleurs, c'était un bailleur allemand, Du moment qu'ils ont su que j'étais virée, ils ont dit « bon, on retire ». Ils ont retiré l'argent et ils ont dit « qu'est-ce qu'on va faire ? ». Et j'ai suggéré « pourquoi pas les mettre dans les commissions ? ». Alors c'est les commissions de l'UICN qui vont gérer ce travail. Ils ont dit « oui, ça marche ». Et ils ont géré l'argent directement en faisant venir des personnes de commission. Et c'est avec cela, avec ce groupement de personnes, ce panel de 60 personnes qui était avec cette tentative de comprendre la co-gestion, qu'on a commencé à travailler. Et dans l'année 2000, il y a eu une énorme chance pour tout ça, c'est que Il est en train de pleuvoir sous toi ? Dans l'année 2000, c'est passé que Le président de la commission de politique environnementale, économique et sociale s'est fâché avec Louis Ceyenne et il a décidé qu'il n'allait même pas se représenter. Il avait pratiquement détruit la commission. Il y avait le congrès à Amman et dans ce congrès, Certaines personnes sont venues me demander si je voulais faire, appliquer pour ça, pour devenir présidente de la commission. et je n'étais absolument pas. Mais j'avais connu quelqu'un avec lequel j'avais travaillé sur le terrain justement à Yémen. Hier soir, j'ai vu un programme sur le Yémen qui m'a bouleversée. Le pays-là est presque mort. Mais cette personne s'appelle Taghi Parwar. Et avec Taghi, on avait travaillé un peu au Yémen pendant quelques années sur des questions justement de co-gestion, participation, e ...
#   'start_bloc': '00:50:04,387',
#   'end_bloc': '00:50:10,213'},
#  {'bloc_id': 'bloc_36',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Il y a plusieurs choses.',
#   'start_bloc': '01:04:25,697',
#   'end_bloc': '01:04:31,078'},
#  {'bloc_id': 'bloc_37',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Ce que vous disiez, c'était d'Urban ?",
#   'start_bloc': '01:04:31,118',
#   'end_bloc': '01:04:32,999'},
#  {'bloc_id': 'bloc_38',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Non. C'était d'Urban, 2003.",
#   'start_bloc': '01:04:32,999',
#   'end_bloc': '01:04:33,099'},
#  {'bloc_id': 'bloc_39',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Et avant, il y avait eu le... Le Montréal, de 1996, c'était le World Conservation Congress, le premier de Montréal. Celui-là, c'était le World Parks Congress. Le World Parks Congress est chaque 10 ans. On vient d'avoir le World Parks Congress à Sydney en 2014. Et là, ça a pris ampleur encore plus. Peut-être que je pourrais te donner les résultats de... Car moi, j'étais en charge de stream de la gouvernance à Durban et aussi de stream sur la gouvernance de Sydney. Et à Sydney, on a fait un travail beaucoup plus structuré, je dirais. Et finalement, la gouvernance avait été... Pas bien compris, pas encore, mais accepté, disons. On a commencé à la faire accepter en 2003, et finalement, Sydney était acceptée, mais encore difficile de prise en compte.",
#   'start_bloc': '01:04:35,039',
#   'end_bloc': '01:04:42,401'},
#  {'bloc_id': 'bloc_40',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Entre les deux, j'avais vu qu'il y avait eu la Dana Declaration.",
#   'start_bloc': '01:05:41,643',
#   'end_bloc': '01:05:44,384'},
#  {'bloc_id': 'bloc_41',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Dana Declaration, oui. Alors, la déclaration de Dana est avant les... 2003, 2002, ça fait. Oui, et ça avait été intéressant, mais sur ça, je me rappelle très bien que Tagui a joué un rôle énorme. Moi, j'ai joué le rôle d'inclure la co-gestion à l'intérieur de ça, car il n'avait pas pris ça. Il y avait deux personnes là qui jouaient un rôle important. C'était une femme... de Great Britain, je me rappelle plus son nom. Mais il y avait aussi Marcus Colchester qui a fait beaucoup de travail sur les peuples autochtones. Il fait encore aujourd'hui énormément, il est vraiment très fort pour la défense des peuples autochtones des forêts. Et elle s'appelle comment ? Je peux la trouver si tu t'intéresses. mais elle était vraiment très académique. Ce n'est pas la chose de Marcus, mais elle était vraiment pouf, pouf, pouf. Et c'était Tagui qui disait, mais comment vous faites à parler des peuples autochtones mobiles sans avoir ici des peuples autochtones ? Oui, heureusement, il est... Il a tout. Il est autochtone. Il est le plus grand défenseur des autochtones mobiles. Il a un PhD qui est à la fois en écologie et en anthropologie. Il parle sept langues couramment, etc. Il est quelqu'un qui n'est pas facile à trouver à chaque angle des rues. Mais voilà. Là, il y avait vraiment encore la vision de dire, il faut comprendre la mobilité, il faut comprendre les peuples autochtones, mais sans les autochtones. Et c'est avec Tagui qu'on donne vraiment du poids au fait d'avoir le plus possible de gens qui parlent de soi-même. Et c'est à cause de ça qu'on a mis en place avant Durban, premier congrès des peuples autochtones mobiles qui était un petit congrès. c'était 20 personnes mais ça nous a pris un temps fou de trouver l'argent pour le faire venir mais ça a été très très intéressant et pas tous mérité d'être là. il ya des gens qui sont des des autochtones français avec le jumbo jet. Ce n'est pas à cause du fait que quelqu'un est autochtone qu'ils n'ont vraiment ni la sensibilité, ni la compréhension, ni vraiment la, comment dirais-je, la légitimité d'être représentant des peuples autochtones. Mais c'est quand même important de dire qu'on ne va pas donner les droits aux gens comme ça, il faut être tous ensemble, qui fait beaucoup de participation d'une certaine façon.",
#   'start_bloc': '01:05:44,944',
#   'end_bloc': '01:05:46,285'},
#  {'bloc_id': 'bloc_42',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Effectivement, pour revenir sur cette question, parce qu'il me semble qu'il y a tout ce mouvement de co-gestion, on peut dire assez vieux, et j'ai l'impression que ça arrive aussi dans des moments à la fois de décolonisation et de... de revendications de droits pour certaines sociétés ?",
#   'start_bloc': '01:09:05,328',
#   'end_bloc': '01:09:37,040'},
#  {'bloc_id': 'bloc_43',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Oui, c'est le mouvement des peuples autochtones qui était en parallèle à tout ça. Ça a pris 20 ans à finalement arriver à la déclaration des droits des peuples autochtones de 2007. Et ça a pris un temps fou. même la déclaration n'a pas changé beaucoup non mais c'est vrai que ces mouvements étaient là était et faisait 2 de fond à tous et que je vais raconter car c'est une vision pour moi de très personnelle et un peu étroite, si tu veux, de ce que j'ai vécu en cherchant d'ouvrir la boîte de la conservation pour la participation dans la conservation qui devient pour différents types de gouvernance pour les ressources naturelles, pour le territoire. Mais à côté, il y a le mouvement des droits des peuples autochtones, il y a aussi le mouvement des droits des « peasant rights » qui n'a pas encore abouti maintenant. Il y a aussi des mouvements des « consumers » maintenant. Il y a beaucoup de ces choses qui se passent en même temps, qui s'entremêlent un tout petit peu, et peut-être pas peut-être pas. Il faudra rentrer maintenant. Peut-être que tu vas te mettre de ce côté-là, car ta tête te doit faire mal.",
#   'start_bloc': '01:09:37,040',
#   'end_bloc': '01:09:46,923'},
#  {'bloc_id': 'bloc_44',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Non, ça va encore. Ça va encore ?',
#   'start_bloc': '01:11:32,913',
#   'end_bloc': '01:11:34,413'},
#  {'bloc_id': 'bloc_45',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Oui.',
#   'start_bloc': '01:11:35,533',
#   'end_bloc': '01:11:35,734'},
#  {'bloc_id': 'bloc_46',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Voilà. — Parce que l'une des questions aussi qui est... En fouillant un peu, j'ai l'impression que sur cette question de droits ou de mouvements autochtones, etc., j'ai l'impression qu'il y a aussi une séparation... En tout cas, j'ai eu le sentiment qu'il y avait une séparation entre, d'un côté, les mouvements canadiens ou de... autour des peuples arctiques ou des Inuits et des Amérindiens, mais qui, j'avais le sentiment, je me trompe certainement, mais j'avais le sentiment qu'il y avait une surreprésentation des peuples autochtones à travers ces figures qui ne recoupaient pas forcément les mêmes problématiques que les autres.",
#   'start_bloc': '01:11:37,314',
#   'end_bloc': '01:11:37,534'},
#  {'bloc_id': 'bloc_47',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Bon, il y a... Il y a une forte... Maintenant, je connais un peu plus de différences entre les autochtones de l'Amérique du Sud, par exemple, de l'Amérique du Nord, de l'Afrique, de l'Asie. Bon, on a une définition de peuples autochtones qui jouent pour tout le monde, mais... Il y a des différences énormes, des différences de réalité, des différences d'approche, même de, si tu veux, les... Les autochtones de l'Amérique du Sud sont très forts, très capables de demander leurs droits. Ils ont réussi à se faire reconnaître depuis. Les autochtones de l'Amérique du Nord, ils sont en train de faire la même chose, même s'ils ont été battus très fort à certains moments. Les autochtones d'Australie ont été presque annihilés et finalement maintenant ils ont une position quasi ridicule de respect, plus de... des façades que des réalités de la part du monde de blancs australiens, car en effet ce qu'ils font est d'être super super super bureaucratiques par rapport aux droits de ces gens-là, quand en réalité je trouve qu'ils sont encore, à mon avis, très fort discriminés du point de vue social, etc. Et ils ne rentrent pas dans le jeu, vraiment. Sauf certains qui sont complètement... comme des gens de différentes descendances européennes. Il y a vraiment des types très, très, très différents d'autochtones. Les Africains, que je connais un peu mieux, sont très grés pour n'importe quoi qu'ils reçoivent. Ils ont été tellement battus et très peu organisés que Pour eux, ça va n'importe quoi. Il y en a d'autres qui sont nés jusqu'au plafond. Il y en a d'autres qui ont fait du business d'être des peuples autochtones, un très pur business. Il y en a d'autres encore qui souffrent énormément les problèmes de droits humains qu'on trouve en Asie. C'est horrible.
appui technique, financier, ce qu'il faut. Et surtout, je trouve que la chose intéressante est à niveau national, Car au niveau national, il faut mettre ensemble des réseaux qui doivent trouver leur pouvoir. On ne peut pas leur donner le pouvoir. On donne, si possible, la chance de se réunir, de se parler, de se connaître, et de dire, bon, les problèmes sont. Alors, comment on y va pour résoudre ces problèmes ? Évidemment, il y a des exemples qui viennent du passé, qu'on peut regarder, on peut comprendre tout, mais... Il faut que chaque groupe... Par exemple, aux Philippines, ils sont en train d'avoir... Bon, ce n'est pas encore tout donné, car ce monsieur qui est venu pour voir maintenant a tout bloqué, mais c'était la 15e lecture au Sénat d'une loi sur les APACs. qui devait pouvoir garantir à un peuple autochtone ou à une communauté qui a déclaré son APAC de pouvoir se défendre de concessions minières, du passage d'une route, etc. Car c'est ça le grand combat aujourd'hui. que les territoires dont la gouvernance devrait justement revenir aux autochtones et aux communautés locales, ceux qui ont les liens avec ce territoire, ceux qui ont la capacité de le conserver, Ces gens-là, ils sont attaqués partout. Il y a cette machine gigantesque qui est en train d'étouffer, de détruire le monde, qui mange tout, mange le territoire, mange les cultures, mange... Les gens, ils mangent même la tête des gens pour dire, mais toi tu es bien ici, mais tu devrais avoir plus ici, là, etc. Ça change tout. Et voilà, alors les consortiums jouent un rôle qui, parfois, moi je passe un temps fou à... En Skype, au téléphone, il y a toutes ces relations à tisser, l'argent à trouver, l'organisation à maintenir en vie. Ça fait un travail, un boulot sans fin. En plus, nous sommes tous presque bénévoles. Et voilà, c'est... La participation n'est pas facile, la participation n'est pas même fun. Ça fait beaucoup de travail. Mais à la fin du compte, ça donne aussi des certains moments de grande satisfaction quand les choses prennent. C'est comme faire de la cuisine. À un certain moment, il y a des choses qui réussissent à veni ...
#   'start_bloc': '01:18:21,983',
#   'end_bloc': '01:18:28,170'},
#  {'bloc_id': 'bloc_50',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Au Philippines, moi justement, j'ai interrogé Marie-Roy la dernière fois, elle me parlait justement, parce que c'est la même personne, Giorgi Carigno, ou des gens comme ça.",
#   'start_bloc': '01:24:28,042',
#   'end_bloc': '01:24:37,813'},
#  {'bloc_id': 'bloc_51',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Giorgi Carigno, tu l'as interviewé Giorgi ?",
#   'start_bloc': '01:24:37,833',
#   'end_bloc': '01:24:40,836'},
#  {'bloc_id': 'bloc_52',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Non, on en a parlé déjà.',
#   'start_bloc': '01:24:40,836',
#   'end_bloc': '01:24:42,198'},
#  {'bloc_id': 'bloc_53',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Oui, alors Georgie est une personne particulière aux Philippines, car il y a trois femmes comme ça qui sont des femmes de pouvoir, très, très, très importantes femmes de pouvoir. Elle, il y a aussi Vicky Tauli-Corpus, qui est aujourd'hui la personne en charge pour les Nations Unies des droits des peuples autochtones et tout ça. Bon, Georgie a travaillé avec le Forest People's Program. Elle a été directrice pendant quelques années, après Marcus Colchester. Je pense que Marcus avait vraiment mis en place quelque chose de très important. Georgie l'a gestionné de façon plus, encore une fois, C'est faire des choses plutôt qu'avoir du pouvoir. Je trouve que c'est un peu différent. Je ne vois pas elle en tant que quelqu'un qui peut informer beaucoup sur la participation.",
#   'start_bloc': '01:24:42,830',
#   'end_bloc': '01:24:57,039'},
#  {'bloc_id': 'bloc_54',
#   'speaker': 'Speaker 1',
#   'bloc_text': "D'accord.",
#   'start_bloc': '01:25:52,974',
#   'end_bloc': '01:25:53,634'},
#  {'bloc_id': 'bloc_55',
#   'speaker': 'Speaker 0',
# ...
#   'start_bloc': '01:51:07,471',
#   'end_bloc': '01:51:11,155'},
#  {'bloc_id': 'bloc_82',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Moi j'ai travaillé sur des conflits environnementaux en France autour des mobilisations de riz-le-vin dans le cadre de pollution ou de problèmes de santé environnementaux. Je m'étais intéressé à comprendre Comment des gens arrivent à la fois à partager des troubles qui peuvent être personnels au départ, et réussir ou pas réussir à en faire un problème collectif. J'ai notamment regardé l'hypersensibilité chimique. Ce qui est intéressant, c'est de voir comment Que c'était quelque chose que les gens n'arrivaient pas finalement à... n'ont pas réussi à construire, en tout cas en France, à construire un mouvement autour de ça.",
#   'start_bloc': '01:53:05,867',
#   'end_bloc': '01:53:25,894'},
#  {'bloc_id': 'bloc_83',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Hypersensibilité. C'est pas facile de faire un mouvement d'une situation très particulière. On imagine que quelqu'un peut changer l'environnement même. Et tu as trouvé quoi en général ?",
#   'start_bloc': '01:54:14,694',
#   'end_bloc': '01:54:16,234'},
#  {'bloc_id': 'bloc_84',
#   'speaker': 'Speaker 1',
#   'bloc_text': "J'avais vu... Parce que l'importance, c'est notamment ce que j'appelle la processus d'enquête, cette manière de... la façon dont se construisent les problèmes à travers les problèmes justement auxquels font face les individus et les personnes. Le problème arrive dans... Le problème collectif se construit à travers des enquêtes que les uns et les autres construisent pour comprendre ce qui arrive. Par exemple, quelqu'un qui ressent tout d'un coup une chose qui lui gratte et son collègue de travail lui dit « mais il y a quelque chose qui ne va pas, pourquoi ? ». Il se met à discuter comme ça de... de l'environnement du travail où il y a fait remonter des problèmes au niveau collectif.",
#   'start_bloc': '01:54:43,639',
#   'end_bloc': '01:55:14,998'},
#  {'bloc_id': 'bloc_85',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Il y a beaucoup de cas en France ?',
#   'start_bloc': '01:55:53,156',
#   'end_bloc': '01:55:55,398'},
#  {'bloc_id': 'bloc_86',
#   'speaker': 'Speaker 1',
#   'bloc_text': "C'est très difficile comme ce n'est pas reconnu médicalement. Il n'y a pas de comptabilité réelle. Aux États-Unis, ils avaient essayé de faire un recensement avec toujours le biais que ça peut importer, ils iraient estimer à 2% de la population, ce qui est beaucoup déjà.",
#   'start_bloc': '01:55:55,398',
#   'end_bloc': '01:55:59,561'},
#  {'bloc_id': 'bloc_87',
#   'speaker': 'Speaker 0',
#   'bloc_text': 'Une sensibilité accrue.',
#   'start_bloc': '01:56:17,457',
#   'end_bloc': '01:56:19,801'},
#  {'bloc_id': 'bloc_88',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Un produit chimique, oui.',
#   'start_bloc': '01:56:20,402',
#   'end_bloc': '01:56:21,784'},
#  {'bloc_id': 'bloc_89',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Ah non, c'est... Et en plus, ce n'est pas dit que les gens qui apparemment n'ont pas de la sensibilité ne soient pas affectés. Mais pour moi ce serait intéressant de voir comment on bâtit une capacité collective d'action. Car c'est là un peu...",
#   'start_bloc': '01:56:21,844',
#   'end_bloc': '01:56:37,511'},
#  {'bloc_id': 'bloc_90',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Parce que j'imagine que dans ces questions de l'air protégé, d'APAC, etc., c'est une question centrale.",
#   'start_bloc': '01:56:51,530',
#   'end_bloc': '01:56:55,692'},
#  {'bloc_id': 'bloc_91',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Oui, c'est une question centrale. Et on a développé une espèce de guide, une espèce de méthodologie pour renforcer les communautés gestionnaires des APAC. Je ne sais pas si ça t'intéresse, si je peux te l'envoyer.",
#   'start_bloc': '01:57:00,994',
#   'end_bloc': '01:57:02,935'},
#  {'bloc_id': 'bloc_92',
#   'speaker': 'Speaker 1',
#   'bloc_text': "D'accord.",
#   'start_bloc': '01:57:19,763',
#   'end_bloc': '01:57:20,083'},
#  {'bloc_id': 'bloc_93',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Mais on part de l'autoconscience, de la conscience critique, comment s'appelait ce brésilien ? Paulo Freire. C'est beaucoup moins théorique de par l'offrir, mais c'est la conscience d'avoir un territoire quand même, et d'avoir conservé un territoire. Est-ce que cette conscience est là ? Et les multiples valeurs de ce territoire, etc. Et après on se demande comment on prend les décisions, est-ce que les décisions sont respectées, comment on les fait respecter, tout ça. Et après on se demande, bon, est-ce qu'il y a des menaces, des problèmes, qu'est-ce qu'il faut faire pour faire face aux menaces, etc. Ça fait un processus et à un certain moment on communique. La chose peut-être la plus importante est quand on sort de la communauté et on commence à penser qu'il faut affecter les grands phénomènes, les phénomènes de type politique, économique, qui nous affectent.",
#   'start_bloc': '01:57:22,199',
#   'end_bloc': '01:57:37,211'},
#  {'bloc_id': 'bloc_94',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Est-ce que ça, localement, affecter ces grands phénomènes, ça suppose nécessairement une structuration de la...',
#   'start_bloc': '01:58:59,465',
#   'end_bloc': '01:59:14,637'},
#  {'bloc_id': 'bloc_95',
#   'speaker': 'Speaker 0',
#   'bloc_text': "La politique nationale, ou bien les décisions prises à plusieurs niveaux qui ont des conséquences. Et pour faire ça... peut pas être une communauté il faut être plusieurs. il faut se mettre en réseau. et la chose intéressante que on peut se mettre en réseau par rapport à l'environnement et il ya d'autres réseaux évidemment il ya des eaux politiques etc. et bon moi je ne peux Je ne trouve pas tellement de mon bien dans les partis politiques. Ça, je trouve vraiment une espèce de machine en soi. Je n'ai pas tellement d'expérience. Ça me semble plus intéressant du point de vue technique, mais bon. Il faut se confronter avec ça, que la gouvernance, c'est justement à propos de ça.",
#   'start_bloc': '01:59:14,677',
#   'end_bloc': '01:59:22,964'},
#  {'bloc_id': 'bloc_96',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Ça me revient, j'avais vu que vous avez participé aussi au colloque Chirac, en 2005, à Paris. À ce moment-là, il y a eu beaucoup de monde qui ont participé, mais c'était... Si vous vous en rappelez un peu...",
#   'start_bloc': '02:00:24,744',
#   'end_bloc': '02:00:32,908'},
#  {'bloc_id': 'bloc_97',
#   'speaker': 'Speaker 0',
#   'bloc_text': "C'était quelque chose à Paris. J'ai participé à plusieurs choses à Paris, surtout que j'étais membre du comité de gouvernance des parcs nationaux de France. Je venais assez souvent, deux fois par an, des choses comme ça. Mais ça a fini. aujourd'hui, ils ont détruit. Oui, ils ont une agence nationale de la biodiversité à la place de ça. Le parc national de France n'existe plus. Bon, c'est toujours comme ça, il y a quelqu'un en haut qui décide.",
#   'start_bloc': '02:00:48,694',
#   'end_bloc': '02:00:51,876'},
#  {'bloc_id': 'bloc_98',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Oui.',
#   'start_bloc': '02:01:43,071',
#   'end_bloc': '02:01:46,452'},
#  {'bloc_id': 'bloc_99',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Il faut organiser, il faut désorganiser, on dépense de l'argent.",
#   'start_bloc': '02:01:46,532',
#   'end_bloc': '02:01:51,113'},
#  {'bloc_id': 'bloc_100',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Et justement, comment vous avez vu arriver ça ? Vu l'arrivée de cette nouvelle institution qui est l'IPBES.",
#   'start_bloc': '02:01:51,293',
#   'end_bloc': '02:01:55,896'},
#  {'bloc_id': 'bloc_101',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Ça je trouve très intéressant quand même. Je trouve que l'IPBES, ça va, peut-être pas te plaire beaucoup ce que je vais dire, mais la CBD a pris beaucoup d'années. pour comprendre des choses. Et à un certain moment, elle était prête à faire ce qu'on appelle l'implémentation. À ce moment-là, il y a eu des gens qui ont dit « Oh, mais c'est trop politisé, il y a des gouvernements qui ont trop influencé les choses ici. Il faut faire quelque chose de plus technique, de plus scientifique. ». Et qu'est-ce qu'ils ont fait ? Ils ont mis en place IPEBES avec exactement le même gouvernement qui ont choisi ce qu'on appelle les mêmes scientifiques. Et pas seulement les mêmes scientifiques, ils ont donné beaucoup d'espace aux peuples autochtones pour le savoir traditionnel, etc. Et Giorgi a été dans ça 1000%. On a eu des Des histoires un peu comme ça. Car elle est vraiment pro-IPBES. Et moi, je pense que l'IPBES a été un désastre colossal. Car on a cherché à réinventer ce qu'on avait déjà et qu'on n'était pas capable de mettre en place. On a des problèmes en face de nous qui sont gigantesques. Et on ne peut pas passer la vie à chercher à faire des plans. Il faut implémenter ces plans. Mais là, l'argent qui aurait dû partir sur l'implémentation a commencé à refaire tourner tout un balai d'experts, de gens, etc. Ça fait des millions, des millions, des millions pour... Des gens comme moi qui peuvent très bien être là, passer des journées sympas avec l'hôtel, avec les restaurants, reconnaître des vieux amis, avoir des histoires sexuelles, et ci et là. C'est bien, c'est très sympa. Mais est-ce qu'on est en train de faire quelque chose de bien pour la conservation de la biodiversité et tout ça ? On a commencé en 92, nous sommes en 2018. Pour cela, je ne suis pas tellement chaude pour cette histoire des pêches, car le moment aujourd'hui, ce n'est pas encore de remuer la sauce, c'est de manger la pâte avec la sauce. mais du fait que les peuples autochtones et ce n'est pas les peuples autochtones c'est les représentants Les peuples autochtones sont là dans cette belle... ont été reconnus de façon beaucoup plus forte qu'avant sur ça. Et voilà que beaucoup de gens n'ont pas eu une vision critique de même dans un team. Et ils se sont mis sur cette histoire. Oui, il faut commencer à zéro. Sans même se rendre compte que la CBD était la convention la plus radicale, la plus progressiste qu'on a. Les groupes de travail sur les aires protégées de la CBD, c'est que justement, on a pu... Le programme de travail qu'on a pu influencer beaucoup auprès d'Urban, on a ajouté tout un élément sur gouvernance, participation, équité et respect des droits, je ne sais pas quoi. Ça devait être implémenté ? Non, ça je ne respecte pas tellement, car j'ai l'impression qu'il y a des choses qui doivent être démontrées, pas seulement blablabla, démontrées. Oui.",
#   'start_bloc': '02:02:02,841',
#   'end_bloc': '02:02:06,003'},
#  {'bloc_id': 'bloc_102',
#   'speaker': 'Speaker 1',
#   'bloc_text': "Oui, ça va, hein. Du coup, l'IPES, c'est vrai, c'est un peu une inclusion de cette... de savoirs locaux ou autochtones dans l'IPES à diminuer leur portée critique ou leur...",
#   'start_bloc': '02:07:01,413',
#   'end_bloc': '02:07:05,034'},
#  {'bloc_id': 'bloc_103',
#   'speaker': 'Speaker 0',
#   'bloc_text': "À mon avis, oui. À mon avis, oui, mais pas seulement du point de vue critique à l'intérieur de l'institution, mais critique... Bien au-delà de ça, critique n'est pas à l'intérieur du discours, mais de voir ce qui se passe, de voir où on est en train de mettre le peu, le grand que nous avons. On va recommencer tout à zéro, à reinventer l'eau chaude, ou on va vraiment faire des choses. On n'a plus le temps de reinventer l'eau chaude. Et ça, je le trouve une forte responsabilité, surtout de ces leaders autochtones qui ont, à mon avis, décidé de leurs propres bénéfices par rapport à d'autres. Je ne devrais pas parler comme ça car je ne connais pas assez. Ni Georgie, ni beaucoup d'autres. Mais je n'aime pas ça, sincèrement. Je trouve qu'il y a des gens qui ont fait même de... du discours autochtone une histoire personnelle importante. Nous tous, nous tirons certains bénéfices. Moi, je suis heureuse de travailler en bénévolat car finalement, je peux me permettre, premièrement, et secondement, je trouve que ce serait plus difficile pour moi de gagner beaucoup pour... pour faire des discours de participation, etc. Ce n'est pas vraiment de jouer un jeu qui soit tellement cohérent à un certain point.",
#   'start_bloc': '02:07:25,804',
#   'end_bloc': '02:07:28,284'},
#  {'bloc_id': 'bloc_104',
#   'speaker': 'Speaker 1',
#   'bloc_text': "On est l'heure pour ne pas ouvrir pour tard. On doit arrêter, je ne sais pas si vous avez d'autres choses à...",
#   'start_bloc': '02:09:22,682',
#   'end_bloc': '02:09:25,605'},
#  {'bloc_id': 'bloc_105',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Ça m'intéresserait beaucoup de savoir où tu vas aller avec tout ça, car c'est vraiment intéressant de comprendre ces questions, mais il faut, d'une certaine façon, se poser des questions de plus en plus dures, de dire, bon, qu'est-ce qu'on va faire, et pourquoi ?",
#   'start_bloc': '02:09:29,428',
#   'end_bloc': '02:09:56,899'},
#  {'bloc_id': 'bloc_106',
#   'speaker': 'Speaker 1',
#   'bloc_text': "C'est une des questions que je n'ose pas trop me poser. La position de chercheur est très confortable.",
#   'start_bloc': '02:09:56,899',
#   'end_bloc': '02:09:59,300'},
#  {'bloc_id': 'bloc_107',
#   'speaker': 'Speaker 0',
#   'bloc_text': "Est-ce qu'il manque ? Oui, nous tous sommes dans des positions privilégiées, d'une façon ou de l'autre. Ou bien nous avons créé pour nous-mêmes des positions de privilège. J'espère sans avoir créé de l'autre côté des positions défavorisées. Car c'est ça un peu la justice aussi. Si tu t'élèves en faisant comme ça, c'est une chose. Si tu t'élèves en cherchant d'élever des autres aussi, c'est une autre histoire. Mais peut-être, je ne sais pas, c'est l'ambition d'influencer des politiques. Oui.",
#   'start_bloc': '02:10:12,807',
#   'end_bloc': '02:10:22,298'},
#  {'bloc_id': 'bloc_108',
#   'speaker': 'Speaker 1',
#   'bloc_text': "De voir ce qui est possible de faire autrement ? On va savoir s'il est possible de faire de la sociologie autrement. Beaucoup de gens ont développé des choses pour éviter d'être dans le surplomb, mais j'ai l'impression que les sociologues, on reste encore très dans une posture au-dessus des autres, en retrait.",
#   'start_bloc': '02:11:03,824',
#   'end_bloc': '02:11:19,468'},
#  {'bloc_id': 'bloc_109',
#   'speaker': 'Speaker 0',
#   'bloc_text': "La France est particulière, ce sens, n'est-ce pas ? Il y a des classes fortes qui se mettent bien à l'écart du reste. Elles parlent de façon différente, elles se comportent de façon différente et tout ça. Bon, c'est peut-être une façon de créer sa propre identité. Nous avons tous besoin d'une identité. Mais bon... Mais ça serait bien de... Peut-être c'est un peu tôt, je ne sais pas, d'avoir une vision de... J'ai l'impression que si on veut vraiment quelque chose dans la vie, on l'obtient. Moi, très franchement, j'ai réussi à faire ce que je voulais faire. Et ça m'a donné une... un sens de responsabilité un peu accru pour dire, mais dammit, si c'est comme ça, ce n'est pas seulement que nous cherchons, cherchons et nous cassons la tête. Si on veut vraiment, si on y met vraiment beaucoup, on y arrive. Alors là, c'est aussi la question de bien penser, de bien organiser, de trouver les bonnes personnes, de s'engager de façon sérieuse. Bon, il y a plus de responsabilités. C'est un peu... Évidemment, il y a plus de responsabilités si tu reconnais des valeurs sociales évidentes, car, à la fin du compte, je t'en fiche de la quantité de souffrance au monde ou bien du fait que l'arbre-là peut exister ou pas, voilà. Ça fiche de tout.",
#   'start_bloc': '02:11:45,664',
#   'end_bloc': '02:11:48,406'},
#  {'bloc_id': 'bloc_110',
#   'speaker': 'Speaker 1',
#   'bloc_text': 'Bon, on va essayer. Merci en tout cas pour...',
#   'start_bloc': '02:13:59,889',
#   'end_bloc': '02:14:03,773'}]

# %%
dict_bloc_id, gb1 = get_bloc(data=gb, column="speaker", new_dataframe=False)
list_bloc_text = write_bloc_in_list(data=gb1, column_of_text = "bloc_text", segment_tag=True, segment_id="id")
with open("../records/2026-02-05_grazia_borrini_in_block.txt" , 'w', newline='') as txt:
    for row in list_bloc_text:
        start = row["start_bloc"]
        end = row["end_bloc"]
        speaker = row["speaker"]
        bloc_text = row["bloc_text"]
        txt.write(f"{row["bloc_id"]}\n")
        txt.write(f"{start} --> {end}\n")
        txt.write(f"{speaker} : {bloc_text}\n\n")

# %%
list_of_dataframe = [gb, mr]
list_of_path = [gb_transcript, mr_transcript]
for n, df in enumerate([gb, mr]):
    dict_bloc_id, df1 = get_bloc(data=df, column="speaker", new_dataframe=False)
    list_bloc_text = write_bloc_in_list(data=df1, column_of_text = "bloc_text", segment_tag=False, segment_id=None)
    with open(f"{list_of_path[n]}_in_bloc.txt" , 'w', newline='') as txt:
        for row in list_bloc_text:
            start = row["start_bloc"]
            end = row["end_bloc"]
            speaker = row["speaker"]
            bloc_text = row["bloc_text"]
            txt.write(f"{row["bloc_id"]}\n")
            txt.write(f"{start} --> {end}\n")
            txt.write(f"{speaker} : {bloc_text}\n\n")

# %% [markdown]
# # Pseudonomyser et anonymiser les locuteurs
#
# Quand on travaille avec des entretiens, il est souvent nécessaire de les pseudonomyser. On peut pour cela utiliser l'outil "find and replace" de son loogiciel de traitement de texte. On peut également le faire avec python, notamment lorsqu'on a de nombreux noms de personnes ou de lieux à remplacer.
#
# C'est ce que propose de faire la fonction ci-dessous.

# %%
def pseudonymiser(original_name, new_name, file, column = None, replace_file=False):
    """
    Pseudonymise un fichier
    ---------------

    original_name : 'string'.
    new_name : 'string'. The pseudonym
    file : path of file to pseudonymise. It could be a csv, srt or txt file.
    column : only if "file" is a csv. Name of the column to pseudonymise
    replace_file: boolean. If false, it create a new file. Else it erases the given file.
    """
    
    if file.split(".")[-1] == "csv":
        with open(file, "r") as csvf:
            reader2 = csv.DictReader(csvf)
            old_row = []
            line_to_override={}
            for n, r in enumerate(reader2):
                old_row.append(r)
                pseudo = r[column].replace(original_name, new_name)
                r[f"pseudo_{column}"] = pseudo
                line_to_override[n] = r
        if replace_file == False:
            new_file = file.replace(".csv", "pseudonymise.csv")
            with open(new_file, 'w', newline='') as csvfile:
                fieldnames = [key for key, value in line_to_override[0].items()]
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                for line, row in enumerate(old_row):
                    data = line_to_override.get(line, row)
                    #print(data)
                    writer.writerow(data)
            return new_file
        else:
            with open(file, 'w', newline='') as csvfile:
                fieldnames = [key for key, value in line_to_override[0].items()]
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                for line, row in enumerate(old_row):
                    data = line_to_override.get(line, row)
                    #print(data)
                    writer.writerow(data)
            return file
    else:
        if replace_file == False:
            find_ext = file.split(".")[-1]
            new_file = file.replace(f".{find_ext}", f"pseudonymise.{find_ext}")
            with open(file, 'r', encoding='utf-8-sig') as txt:
                with open(new_file, 'w', encoding='utf-8') as txt2:
                    for line in txt:
                        new_line = re.sub(original_name, new_name, line)
                        txt2.write(new_line)
            return new_file
        else:
            for line in fileinput.input(file, inplace = 1): 
                print(line.replace(original_name, new_name))
            return file

# %%
name_to_replace= {"Speaker 1": "Chercheur", "Speaker 0": "Enquêtée"}

n = 0
for nom, new_name in name_to_replace.items():
    n +=1
    if n == 1:
        nom_fichier = pseudonymiser(nom, new_name, file = "../records/2026-02-05_grazia_borrini_in_block.txt", column= "speaker", replace_file=False)
    else:
        pseudonymiser(nom, new_name, file = nom_fichier, column= "pseudo_speaker", replace_file=True)

# %% [markdown]
# # Compter un ou plusieurs mots
#
# Nous créons maintenant un compteur de mots (équivalent à la fonction "find" dans word). On utiliser pour cela des expressions régulières (Regex). Les regex permettent par exemple de retrouver tous les mots contenant une même racine (ou terminaisons). Dans l'exemple ci-dessous, nous allons rechercher tout les mots qui contiennent la racine "participat" : participation, participatif, participative, participatory, etc.
#
# Nous allons faire la recherche sur deux types de fichier : un fichier texte (.txt) et un fichier csv.
#
# ## Trouver les occurences de l'adjectif "participative" dans l'entretien de Grazia Borrini
#
# Nous commençons par explorer l'entretien de Grazia Borrini en utilisant le fichier texte obtenu après avoir regroupés les segments en bloc. Ce fichier s'appelle `2026-02-05_grazia_borrini_in_block.txt`.
#
# Pour cela, j'ouvre le fichier et je "mets" son contenu dans l'objet "texte".

# %%
with open("../records/2026-02-05_grazia_borrini_in_block.txt","r") as f:
    texte = f.read()

len(texte)
# Out:
# 3834932

# %% [markdown]
# Une fois l'objet `texte` créé, on peut effectuer différents décomptes :
#
# * Si je veux connaître le nombre de caractères, j'exécute la commande `len(texte)` (len pour length).
# * Si je veux connaître le nombre de mots/chaînes de caractères : `len(texte.split())`. La fonction `.split()` découpe le texte à chaque fois qu'elle trouve une espace.
# * Si je veux connaître le nombre d'occurrence d'un mot quelconque : `texte.count("le mot que je cherche")`.
#
# Essayez ces différentes commandes dans la cellule ci-dessous

# %%
texte.count("participative")
# Out:
# 170

# %% [markdown]
# Bien sûr, il est possible d'inscrire les résultats dans des objets.

# %%
nb_caractere = len(texte)
nb_string = len(texte.split())
occ_participat = texte.count("participative")

print("Nombre de caractères ",nb_caractere) # affiche le nombre de chaînes de caractère
print("Longueur du texte ", nb_string) # affiche le nombre de chaînes de caractère
print("Occurence du terme 'participative' ", occ_participat) # compte le nombre de fois que participative apparaît
# Out:
# Nombre de caractères  3834932
# Longueur du texte  662412
# Occurence du terme 'participative'  170

# %% [markdown]
# Combien de fois le terme "participative" apparaît dans l'entretien de Grazia Borrini ? Quel est le problème avec cette clé de recherche ?

# %% [markdown]
# C'est en ce sens que les regex sont utiles, que ce soit dans le cadre des traitements que nous faisons, mais aussi dans tous les cas où vous faites une recherche sur word, le web, etc. Elles permettent de préciser la recherche en l'élargissant ou en la spécifiant. Par exemple `texte.count()` compte les formes singulières et plurielles. Mais parfois, il peut intéressant de compter le nombre de fois qu'un mot est mis au singulier ou mis au pluriel.
#
# ```
# Il existe de nombreuses ressources sur le web pour comprendre le fonctionnement des regex et le rôle des différentes "balises". Vous pouvez en particulier consulter le tutoriel sur le site W3school : [https://www.w3schools.com/python/python_regex.asp](https://www.w3schools.com/python/python_regex.asp)```

# %%
test = "Il a une fois participative dans sciences participatives."

test.count("participative")
# Out:
# 2

# %% [markdown]
# La fonction ci-dessous est similaire à la fonction test.count(mot_a_chercher)

# %%
re.findall(r"participative", test)
# Out:
# ['participative', 'participative']

# %% [markdown]
# * Si on ne cherche que les formes au singulier:

# %%
re.findall(r"participative\b", test) # le "\b" indique que l'on recherche toutes les chaines de caractères finissant par "participative", c'est-à-dire le mot "participative" suivi d'un espace ou d'un signe de ponctuation
# Out:
# ['participative']

# %% [markdown]
# * Si on ne cherche que les formes au pluriel:

# %%
re.findall(r"participatives", test)
# Out:
# ['participatives']

# %% [markdown]
# **OU**

# %%
re.findall(r"participatives\b", test)
# Out:
# ['participatives']

# %%
re.findall(r"participative\w\b", test)
# Out:
# ['participatives']

# %% [markdown]
# * Si on cherche les deux formes, mais que l'on souhaite les distinguer

# %%
re.findall(r"participatives?", test) # Le point d'interrogation signifie qu'on cherche toutes les occurrence de participative contenant un "s" ou aucun.
# Out:
# ['participative', 'participatives']

# %% [markdown]
# **OU**

# %%
re.findall(r"participatives*\b", test) # L'astérisque signifie qu'on cherche toutes les occurrence de participative contenant aucun "s" ou plus
# Out:
# ['participative', 'participatives']

# %% [markdown]
# **OU**

# %%
re.findall(r"participative.", test) #La balise ".\b" signifie qu'on cherche toutes les occurrence de participative suivi de n'importe quel caractère en bout de chaîne
# Out:
# ['participative ', 'participatives']

# %% [markdown]
# Dans la cellule ci-dessous, on recherche fois toutes les fois qu'apparaît la racine "participat" quelque soit la terminaison (participation, participatif, participatory, etc.)

# %%
words_with_participat = re.findall(r"participat\w*", texte.lower()) 
print("Le nombre de mots contenant la racine 'participat' est : ", len(words_with_participat))
print("Voici la liste des différentes formes retrouvées : ", set(words_with_participat))
# Out:
# Le nombre de mots contenant la racine 'participat' est :  1166
# Voici la liste des différentes formes retrouvées :  {'participation', 'participatives', 'participative', 'participatory'}

# %% [markdown]
# En fait, la fonction `re.findall()` "retourne" la liste de toutes les occurrences des termes commençant par "participat". Si on veut la liste des différentes formes sans les doublons, on écrit l'objet contenant la liste à l'intérieur de la fonction `set()`.

# %%
print("La liste des occurrences de 'participat' : ", words_with_participat[0:10])
print("Voici la liste des différentes formes retrouvées sans les doublons : ", set(words_with_participat))
# Out:
# La liste des occurrences de 'participat' :  ['participatives', 'participatives', 'participative', 'participation', 'participative', 'participation', 'participative', 'participation', 'participative', 'participation']
# Voici la liste des différentes formes retrouvées sans les doublons :  {'participation', 'participatives', 'participative', 'participatory'}

# %% [markdown]
# ### Exercice
#
# Pour chaque terme contenu dans la liste `words_with_participat`, comptez le nombre d'occurrences dans les entretiens de Grazia Borrini, puis dans celui de Marie Roué.

# %%
# Out:
# ['les sciences participatives',
#  'les sciences participatives',
#  'appeler recherche participative',
#  'idée de participation',
#  'de pratique participative',
#  'idée de participation',
#  'appeler recherche participative',
#  'idée de participation',
#  'de pratique participative',
#  'idée de participation',
#  'appeler recherche participative',
#  'idée de participation',
#  'de pratique participative',
#  'idée de participation',
#  'appeler recherche participative',
#  'idée de participation',
#  'de pratique participative',
#  'idée de participation',
#  'appeler recherche participative',
#  'idée de participation',
#  'de pratique participative',
#  'idée de participation',
#  'appeler recherche participative',
#  'idée de participation',
#  'de pratique participative',
#  'idée de participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'avec cette participation',
#  'avec cette participation',
#  'avec cette participation',
#  'avec cette participation',
#  'avec cette participation',
#  'avec cette participation',
#  'avec cette participation',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'histoire de participatory',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'des méthodes participatives',
#  'ces méthodes participatives',
#  'principes de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'de la participation',
#  'sérieusement leur participation',
#  'parler de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'beaucoup de participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'pour la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'de la participation',
#  'sur la participation',
#  'sur la participation',
#  'sur la participation',
#  'sur la participation',
#  'sur la participation',
#  'sur la participation',
#  'sur la participation',
#  'sur la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'comme la participation',
#  'trop de participation',
#  'trop de participation',
#  'trop de participation',
#  'trop de participation',
#  'trop de participation',
#  'trop de participation',
#  'moment cette participation',
#  'on appelle participation',
#  'moment cette participation',
#  'on appelle participation',
#  'de la participation',
#  'que la participation',
#  'que la participation',
#  'que la participation',
#  'que la participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation',
#  'discours de participation']

# %% [markdown]
# * Trouver une regex pour identifier les expressions contenant la racine "participat" comme "science participative" ou "démocratie participative".

# %% [markdown]
# ### Mettre en gras les mots recherchés
#
# Maintenant que nous avons identifiés les termes commençant par "participat", il peut être intéressant des les "taguer" dans le texte pour les repérer plus facilement à la lecture des entretiens. Ici, on choisit de les signaler en les encadrant de deux astérisques, mais on peut aussi utiliser des balises html, xml, etc.

# %%
with open("../records/2026-02-05_grazia_borrini_in_block.txt","r") as f:
    texte = f.readlines()

for s in texte:
    if re.search(r'participat\w+', s.lower()):
        for w in set(re.findall(r'participat\w+', s.lower())):
            s = re.sub(w, f'**{w}**', s.lower())
        print(s)
# Out:
# speaker 1 : <seg_1>je suis arrivé en post-doctorat au muséum national d'historie naturelle l'année dernière, en septembre. c'est un projet porté par à la fois stéphanie duvaille et les écologues qui ont mis au point ce qu'on appelle les sciences **participatives** ou en anglais les citizen science.</seg_1><seg_2>je suis arrivé en post-doctorat au muséum national d'historie naturelle l'année dernière, en septembre. c'est un projet porté par à la fois stéphanie duvaille et les écologues qui ont mis au point ce qu'on appelle les sciences **participatives** ou en anglais les citizen science.</seg_2>
#
# speaker 1 : <seg_6>? et puis stéphanie duval et son labo qui est plutôt... qu'on pourrait appeler recherche **participative**. là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes. et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de **participation**, de pratique **participative** dans la production de connaissances. donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc. dans ce cadre, j'aimerais qu'on revienne un peu à la fois sur votre parcours et comment vous avez discuté cette idée de **participation**, comment ça s'intègre dans votre trajectoire, etc.</seg_6><seg_7>? et puis stéphanie duval et son labo qui est plutôt... qu'on pourrait appeler recherche **participative**. là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes. et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de **participation**, de pratique **participative** dans la production de connaissances. donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc. dans ce cadre, j'aimerais qu'on revienne un peu à la fois sur votre parcours et comment vous avez discuté cette idée de **participation**, comment ça s'intègre dans votre trajectoire, etc.</seg_7><seg_8>? et puis stéphanie duval et son labo qui est plutôt... qu'on pourrait appeler recherche **participative**. là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes. et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de **participation**, de pratique **participative** dans la production de connaissances. donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc. dans ce cadre, j'aimerais qu'on revienne un peu à la fois sur votre parcours et comment vous avez discuté cette idée de **participation**, comment ça s'intègre dans votre trajectoire, etc.</seg_8><seg_9>? et puis stéphanie duval et son labo qui est plutôt... qu'on pourrait appeler recherche **participative**. là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes. et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de **participation**, de pratique **participative** dans la production de connaissances. donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc. dans ce cadre, j'aimerais qu'on revienne un peu à la fois sur votre parcours et comment vous avez discuté cette idée de **participation**, comment ça s'intègre dans votre trajectoire, etc.</seg_9><seg_10>? et puis stéphanie duval et son labo qui est plutôt... qu'on pourrait appeler recherche **participative**. là aussi, il y a beaucoup de termes très proches, mais qui mettent des méthodes différentes. et c'est dans ce cadre-là qu'elle m'a indiqué qu'à la fois vos travaux et peut-être l'environnement, la communauté dans laquelle vous étiez, ont nourri cette idée de **participation**, de pratique **participative** dans la production de connaissances. donc, je fais des entretiens avec des acteurs qui permettraient d'éclairer un peu cet univers et comment ça s'est construit, etc. dans ce cadre, j'aimerais qu'on revienne un peu à la fois sur votre parcours et comment vous avez discuté cette idée de **participation**, comment ça s'intègre dans votre trajectoire, etc.</seg_10><seg_11>? et puis stéphanie duval et son labo qui est pl ...
#
pas parler comme ça car je ne connais pas assez. ni georgie, ni beaucoup d'autres. mais je n'aime pas ça, sincèrement. je trouve qu'il y a des gens qui ont fait même de... du discours autochtone une histoire personnelle importante. nous tous, nous tirons certains bénéfices. moi, je suis heureuse de travailler en bénévolat car finalement, je peux me permettre, premièrement, et secondement, je trouve que ce serait plus difficile pour moi de gagner beaucoup pour... pour faire des discours de **participation**, etc. ce n'est pas vraiment de jouer un jeu qui soit tellement cohérent à un certain point.</seg_893><seg_894>à mon avis, oui. à mon avis, oui, mais pas seulement du point de vue critique à l'intérieur de l'institution, mais critique... bien au-delà de ça, critique n'est pas à l'intérieur du discours, mais de voir ce qui se passe, de voir où on est en train de mettre le peu, le grand que no ...

# %% [markdown]
# Si on veut enregistrer le résultat dans un fichier .txt

# %%
with open("../records/2026-02-05_grazia_borrini_in_block.txt" , 'w', newline='') as txt:
    for s in texte: 
        txt.write(s)

# %% [markdown]
# La cellule ci-dessous permet de faire la même recherche dans des données présentées dataframe (tableur)

# %%
dict_n_word = {}
dict_word = {}
for n, seg in enumerate(gb.id):
    row = gb.iloc[n]
    n_word = len(re.findall(r'participat\w+', row["text"].lower()))
    word = [x for x in set(re.findall(r'participat\w+', row["text"].lower()))]
    if n_word > 0:
        
        dict_word[seg]= "|".join(word)
        dict_n_word[seg] = n_word

dict_word
gb["partipat"] = gb.id.map(dict_word.get)
gb["nb_partipat"] = gb.id.map(dict_n_word.get)
gb.loc[gb.nb_partipat>0]
# Out:
#           id         start           end    speaker  \
# 1      seg_2  00:00:09,299  00:00:19,930  Speaker 1
# 6      seg_7  00:00:35,597  00:00:43,638  Speaker 1
# 8      seg_9  00:00:53,782  00:01:14,258  Speaker 1
# 10    seg_11  00:01:24,204  00:01:37,453  Speaker 1
# 14    seg_15  00:01:56,727  00:02:08,678  Speaker 0
# 54    seg_55  00:06:24,104  00:06:32,788  Speaker 0
# 136  seg_137  00:17:08,477  00:17:27,063  Speaker 0
# 140  seg_141  00:17:43,408  00:17:53,357  Speaker 0
# 183  seg_184  00:23:29,051  00:23:41,761  Speaker 0
# 184  seg_185  00:23:41,801  00:24:07,136  Speaker 0
# 205  seg_206  00:26:42,128  00:27:07,692  Speaker 0
# 422  seg_423  00:56:02,771  00:56:10,900  Speaker 0
# 430  seg_431  00:57:02,805  00:57:28,675  Speaker 0
# 442  seg_443  00:58:39,870  00:58:54,746  Speaker 0
# 449  seg_450  00:59:53,492  01:00:34,485  Speaker 0
# 472  seg_473  01:03:42,961  01:03:57,333  Speaker 0
# 518  seg_519  01:08:52,377  01:09:04,098  Speaker 0
# 523  seg_524  01:10:02,015  01:10:38,353  Speaker 0
# 582  seg_583  01:19:46,695  01:20:23,905  Speaker 0
# 601  seg_602  01:23:54,437  01:24:06,924  Speaker 0
# 616  seg_617  01:25:47,752  01:25:52,954  Speaker 0
# 747  seg_748  01:46:00,840  01:46:10,786  Speaker 0
# 755  seg_756  01:47:26,042  01:47:30,205  Speaker 0
# 757  seg_758  01:47:48,810  01:48:03,015  Speaker 1
# 758  seg_759  01:48:03,015  01:48:07,938  Speaker 0
# 766  seg_767  01:49:26,072  01:49:27,533  Speaker 0
# 768  seg_769  01:49:42,605  01:49:51,972  Speaker 1
# 884  seg_885  02:06:05,250  02:06:42,979  Speaker 0
# 900  seg_901  02:08:47,389  02:09:10,129  Speaker 0
#
#                                                   text  start_in_ms  \
# 1    C'est un projet porté par à la fois Stéphanie ...        9.299
# 6    Et puis Stéphanie Duval et son labo qui est pl...       35.597
# 8    Et c'est dans ce cadre-là qu'elle m'a indiqué ...       53.782
# 10   Dans ce cadre, j'aimerais qu'on revienne un pe...       84.204
# 14   La raison de l'intérêt pour la participation, ...      116.727
# 54   Alors, bon... Vous aimeriez faire quelque chos...      384.104
# 136  Et c'est sur ça que, moi je travaillais avec b...     1028.477
# 140  Ça veut dire, oui, la participation de la comm...     1063.408
# 183  Et là, c'était justement là qu'on a commencé à...     1409.051
# 184  Car ces méthodes participatives donnaient la f...     1421.801
# 205  À la fin, on avait ce principe de travail à l'...     1602.128
# 422  Et avec Taghi, on avait travaillé un peu au Yé...     3362.771
# 430  Et ça nous a permis de faire de la participati...     3422.805
# 442  Et avec lui, on travaillait sur air protégé, é...     3519.870
# 449  Il y a eu des moments forts, par exemple un mo...     3593.492
# 472  Et c'est pour cela que je n'aime pas tellement...     3822.961
# 518  Mais c'est quand même important de dire qu'on ...     4132.377
# 523  même la déclaration n'a pas changé beaucoup no...     4202.015
# 582  Et l'idée était justement de faire de la parti...     4786.695
# 601  Et voilà, c'est... La participation n'est pas ...     5034.437
# 616  Je ne vois pas elle en tant que quelqu'un qui ...     5147.752
# 747  Quand on est un peu solitaire, quand on est él...     6360.840
# 755  Trop de participation peut être tellement fati...     6446.042
# 757  À quel moment cette participation, ce qu'on ap...     6468.810
# 758  Oui, on n'arrive pas à faire ce qu'on voulait ...     6483.015
# 766                    La participation est difficile.     6566.072
# 768  Là aussi, c'est complètement différent, mais ç...     6582.605
# 884  Sans même se rendre compte que la CBD était la...     7565.250
# 900  Moi, je suis heureuse de travailler en bénévol...     7727.389
#
#      end_in_ms   bloc_id                                          bloc_text  \
# 1       19.930    bloc_0  Je suis arrivé en post-doctorat au Muséum Nati...
# 6       43.638    bloc_4  ? Et puis Stéphanie Duval et son labo qui est ...
# 8       74.258    bloc_4  ? Et puis Stéphanie Duval et son labo qui est ...
# 10      97.453    bloc_4  ? Et puis Stéphanie Duval et son labo qui est ...
# 14     128.678    bloc_5  Oui, très volontiers. Mais en général, j'aimer...
# 54     392.788   bloc_19  Non, je ne connais pas tellement ce travail. O...
# 136   1047.063   bloc_21  J'étais en train de lire un article sur la rel...
# 140   1073.357   bloc_23  par ces médecins qui étaient là, qui d'une cer...
# 183   1421.761   bloc_25  Et ce n'est pas seulement les tertiaires ou le...
# 184   1447.136   bloc_25  Et ce n'est pas seulement les tertiaires ou le...
# 205   1627.692   bloc_25  Et ce n'est pas seulement les tertiaires ou le...
# 422   3370.900   bloc_35  Moi j'espère, car moi j'ai trouvé ça génial et...
# 430   3448.675   bloc_35  Moi j'espère, car moi j'ai trouvé ça génial et...
# 1                 participatives          1.0
# 6                  participative          1.0
# 8    participation|participative          2.0
# 10                 participation          1.0
# 14                 participation          1.0
# 54                 participation          1.0
# 136                participatory          2.0
# 140                participation          1.0
# 183               participatives          1.0
# 184               participatives          1.0
# 205                participation          1.0
# 422                participation          1.0
# 430                participation          1.0
# 442                participation          1.0
# 449                participation          1.0
# 472                participation          1.0
# 518                participation          1.0
# 523                participation          1.0
# 582                participation          2.0
# 601                participation          2.0
# 616                participation          1.0
# 747                participation          1.0
# 755                participation          1.0
# 757                participation          2.0
# 758                participation          1.0
# 766                participation          1.0
# 768                participation          1.0
# 884                participation          1.0
# 900                participation          1.0

# %% [markdown]
# Le problème de cette méthode est qu'il faut connaître a priori les termes que l'on souhaite rechercher. Nous allonrs maintenant voir comment faire ressortir les termes spécifiques de l'entretien.

# %% [markdown]
# # Identifier les termes "spécifiques" d'un entretien

# %% [markdown]
# ## Le Term Frequency-Inverse Document Frequency (TF-IDF)
#
# Le "Term Frequency-Inverse Document Frequency" (TF-IDF) est un indice statistique utilisé dans la recherche d'information et l'exploration de documents. Il permet de "mesurer" l'importance d'un terme dans un document comparativement à un ensemble de documents. Au sens du "TF-IDF", un mot est important dans un document lorsqu'il apparait plus fréquement que dans le reste du corpus. Par exemple, si dans un entretien l'expression "savoirs locaux" apparaît 10 fois alors que dans les autres il n'apparaît jamais, on peut supposer que c'est une expression "importante" pour la personne qui la cite.
#
# Les éléments qui vont suivre permettent de calculer ce TF-iDF. Nous allons d'abord voir comment le calculer 'from scratch', afin de comprendre les différents élements qui entre dans le calcul de l'indice au cas où voudriez le faire dans excel par exemple. Puis, nous utiliserons des modules pythons qui permettent de le faire de façon plus "concise".
#
# Le calcul du TF-IDF suppose au préalable de "nettoyer" les textes : le passer en petite casse, retirer les signes de ponctuation et les "stop words" (mots vides en français). Les "stop words" sont des mots tellement communs qu'ils n'apportent théoriquement aucune information sur le contenu du texte. Les articles (la, le, les, de, du, des, etc.), les auxilliaires (être, avoir) sont généralement considérés comme des stop words.
#
# Plusieurs modules sous Python proposent des listes de "stop words". Je vous propose d'utiliser les modules "Spacy" et "Nltk" conçues spécialement pour le traitement automatique des langues.
#
# ### Installer et charger Spacy
#
# Spacy n'est pas encore installé. Pour cela nous ouvrons une cellule de code et écrivons `!pip install spacy`

# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.11-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer_slim-0.23.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/python/lib/python3.13/site-packages (from spacy) (4.67.2)
# Requirement already satisfied: numpy>=1.19.0 in /opt/python/lib/python3.13/site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/python/lib/python3.13/site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/python/lib/python3.13/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /opt/python/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/python/lib/python3.13/site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/python/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/python/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/python/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/python/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.5 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting typer>=0.23.0 (from typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading typer-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in /opt/python/lib/python3.13/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.0)
# Requirement already satisfied: click>=8.0.0 in /opt/python/lib/python3.13/site-packages (from typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading rich-14.3.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/python/lib/python3.13/site-packages (from typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/python/lib/python3.13/site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/python/lib/python3.13/site-packages (from jinja2->spacy) (3.0.3)
# Downloading spacy-3.8.11-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 102.9 MB/s  0:00:00 eta 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (254 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (133 kB)
# Downloading preshed-3.0.12-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (835 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 835.9/835.9 kB 75.6 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 87.6 MB/s  0:00:00
# Downloading thinc-8.3.10-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 93.4 MB/s  0:00:00
# Downloading blis-1.3.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 98.1 MB/s  0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer_slim-0.23.0-py3-none-any.whl (3.4 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading typer-0.23.0-py3-none-any.whl (56 kB)
# Downloading rich-14.3.2-py3-none-any.whl (309 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, shellingham, murmurhash, mdurl, cymem, cloudpathlib, catalogue, blis, srsly, preshed, markdown-it-py, rich, confection, typer, thinc, typer-slim, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [spacy]m20/21 [spacy]wn-it-py]
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.12 rich-14.3.2 shellingham-1.5.4 smart-open-7.5.0 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 typer-0.23.0 typer-slim-0.23.0 wasabi-1.1.3 weasel-0.4.3
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Une fois spacy installé, nous allons télécharger le modèle de langue dont on n'a besoin. Dans le cas des entretiens utilisés pour l'atelier, on prend le modèle français. Mais il existe d'autres langues : l'anglais bien sûr, mais aussi l'allemand, le chinois, le polonais, etc.
#
# Vous trouverez les modèles de langue existant ici  : [https://spacy.io/models](https://spacy.io/models)

# %%
# !python -m spacy download fr_core_news_md
# Out:
# Collecting fr-core-news-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_md-3.8.0/fr_core_news_md-3.8.0-py3-none-any.whl (45.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 100.0 MB/s  0:00:00eta 0:00:01
# Installing collected packages: fr-core-news-md
# Successfully installed fr-core-news-md-3.8.0
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')

# %% [markdown]
# ### Les stop words proposés par Spacy
#
# Enfin, on peut importer le module spacy, charger le modèle et imprimer la liste des stop words

# %%
import spacy
nlp = spacy.load('fr_core_news_md')
print(f"Il y a {len(nlp.Defaults.stop_words)} termes dans la liste des stopwords de Spacy")
print(nlp.Defaults.stop_words)
# Out:
# Il y a 507 termes dans la liste des stopwords de Spacy
# {'celui', 'tout', 'huit', 'devra', 'hi', 'mes', 'ha', 'ces', 'nos', 'quant', 'c’', 'stop', 'mêmes', 'aurait', 'nous', 'procedant', 'dix-sept', "s'", 'quatre', "quelqu'un", 'diverse', 'auraient', 'trois', 'aupres', 'etaient', 'serait', 'auxquelles', 'qui', 'quelconque', 'dix-neuf', 'quoi', 'ce', 'da', 'doit', 'tienne', 'fait', 'vais', 't’', 'comment', 'aussi', 'aie', 'là', 'ô', 'apres', 'anterieure', 'envers', 'elles-memes', 'merci', 'o', 'mon', 'elle-meme', 'cinq', 'afin', 'moindres', 'vingt', 'memes', 'seules', 'cinquantaine', 'dessus', 'lui-meme', 'ho', 'onzième', 'siennes', 'après', 'néanmoins', 'plusieurs', 'première', 'nombreuses', 'es', 'revoilà', 'jusqu', 'celle-là', 'relative', 'trente', 'cet', 'notre', 'ton', 'avais', 'semblable', 'comme', 'faisant', 'septième', 'ai', 'votres', 'suivante', 'ta', 'jusque', 'alors', 'chacun', 'facon', 'rendre', 'du', 'bat', 'celui-la', 'quelle', 'certains', 'egalement', 'anterieures', 'tiennes', 'car', 'dixième', 'façon', 'et', 'hep', 'seulement', 'fais', 'hue', 'differentes', 'nôtre', 'plutot', 'ont', 'surtout', 'desquels', 'elle-même', 's’', 'différents', 'diverses', 'excepté', 'sauf', 'doivent', 'sont', 'ça', 'seraient', 'avait', 'differente', 'pourrait', 'tenant', 'que', 'sous', 'douzième', 'nombreux', 'étaient', 'dans', 'meme', 'avaient', 'huitième', 'durant', 'celle', 'telles', 'compris', 'tu', 'antérieur', 'chacune', 'autrui', 'ou', 'vas', 'préalable', 'etre', 'quelque', 'tente', 'malgré', 'retour', 'permet', 'eux-mêmes', 'tres', 'quels', 'cinquantième', 'importe', 'etait', 'semble', 'celui-ci', 'quatrième', 'devant', 'souvent', 'relativement', 'antérieure', 'dire', 'pas', 'chaque', 'antérieures', "n'", 'deja', 'partant', 'unes', 'deux', 'l’', 'lorsque', 'parle', 'abord', 'maint', 'vos', 'outre', 'm’', 'ses', 'dès', 'au', 'celle-ci', 'moi', 'treize', 'à', 'ès', 'dessous', 'tels', 'eh', 'vont', 'dedans', 'suivants', 'seront', 'dite', 'celles-là', 'lui-même', 'pouvait', 'autre', 'tous', 'lui', 'sinon', 'puis', 'restant', 'faisaient', 'certain', 'laquelle', 'le', 'celles', 'as', 'si', 'neuvième', 'cette', 'pres', 'suffit', "d'", 'nôtres', 'uns', 'pourrais', 'différentes', 'troisième', 'dit', 'ma', 'pourquoi', 'specifique', 'via', 'ouvert', 'soi', 'eux', 'environ', 'ah', 'aux', 'de', 'certaine', 'effet', 'n’', 'proche', 'j’', 'cinquante', 'lors', 'divers', 'les', 'sa', 'quelques', 'pendant', 'celui-là', 'directement', 'je', 'derriere', 'où', 'quiconque', 'vôtre', 'parfois', 'nouveau', 'donc', 'precisement', 'semblent', 'peut', 'troisièmement', 'pu', 'une', 'désormais', 'sans', 'peux', 'hormis', 'quatre-vingt', 'sixième', 'cent', 'plutôt', 'ci', 'quant-à-soi', 'seule', 'tend', 'ait', 'toute', 'longtemps', 'la', 'en', 'maintenant', 'restent', 'six', 'allons', 'delà', 'tant', 'un', 'houp', 'soi-meme', 'des', 'bas', 'quoique', 'encore', 'près', 'cela', 'aura', 'peu', 'na', 'miens', 'toutes', 'quel', 'directe', 'voila', 'â', 'exactement', 'i', 'précisement', 'toujours', 'miennes', 'gens', 'revoila', 'elles', 'sur', 'hem', 'd’', "m'", 'ceux', 'différent', 'moi-meme', 'parce', 'parlent', 'moi-même', 'suit', "l'", 'sera', 'assez', 'qu’', 'tellement', 'être', 'soi-même', 'neanmoins', 'differents', 'mais', 'tes', 'derrière', 'votre', 'basee', 'entre', 'etant', 'eu', 'soit', 'hé', 'quelles', 'ceux-ci', 'elle', "t'", 'dix-huit', 'ne', 'selon', 'par', 'lequel', 'specifiques', 'toi-meme', 'ouverte', 'quarante', 'dix', 'également', 'vous', 'avant', 'premier', "qu'", 'deuxièmement', 'vé', 'avoir', 'onze', 'concernant', 'ils', 'peuvent', 'même', 'malgre', 'voici', 'nous-mêmes', 'suis', 'suivant', 'dont', 'debout', 'allaient', 'different', 'certaines', 'suffisante', 'déja', 'ainsi', 'puisque', 'seuls', 'elles-mêmes', 'chez', 'juste', 'autres', 'son', 'possibles', 'touchant', 'sienne', 'cinquième', 'suivantes', 'deuxième', "j'", 'vous-mêmes', 'voilà', 'devers', 'sept', 'spécifique', 'te', 'ceci', 'celles-ci', 'avons', 'nul', 'mienne', 'hou', 'ceux-là', 'tien', 'soixante', 'moins', 'feront', 'telle', 'e ...

# %% [markdown]
# ### Les stop words proposés par le module nltk

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# %%
stopwords.words("french")
print(f"Il y a {len(stopwords.words("french"))} termes dans la liste des stopwords de Spacy")
print(stopwords.words("french"))
# Out:
# Il y a 157 termes dans la liste des stopwords de Spacy
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent']

# %% [markdown]
# ### Nettoyage du texte
#
# Nous allons "nettoyer" le texte de l'entretien de Grazia Borrini et le "tokenizer" (i.e. diviser en mot). Nous allons par ailleurs travailler au niveau des blocs pour voir quels sont les thèmes qui émergent au fil de l'entretien ou ceux qui reviennent. Par défaut, aucun stopword n'est retiré.

# %%
def cleaner(text, lower_case = True, remove_stopword=None):
    if lower_case == True:
        text = text.lower()
    else:
        pass
    text = re.sub(r"http\S+", "", text) # remove urls
    text = re.sub("’", "'",text) #replace "’" by "'"
    text = re.sub("'", "' ",text) #replace "’" by "'"
    text = " ".join(re.sub("[^a-zA-Zàâäéèêëïîôöùûüÿçß\\-]+", " ", text).lower().split()) #remove hashtag, arobase, HTML character
    text = re.sub(r"\b[a-zA-Z].\b", "", text)
    if remove_stopword == None:
        split_text = text.split() # 
    else:
        split_text = [x for x in text.split() if x not in remove_stopword]
        text = ' '.join(split_text)
    
    return text, split_text

# %% [markdown]
# La fonction `cleaner()` prend en entrée un texte (un string en langage informatique). L'argument "remove_stopword" prend une liste de termes que l'on souhaite retirer pour l'analyse. Elle retourne ensuite deux objets :
# * la phrase "nettoyée", c'est-à-dire sans ponctuation, sans caractères spéciaux et en petite casse (on peut préciser ̀`lower_case = False` si on veut garder les majuscules)
# * la phrase tokenizée
#
# **Essayons-là!**

# %%
phrase = "Le chat mange une souris. La souris est mangée par un chat. La souris que le chat a mangée! #souris #chat. C'est le chat qui mange la souris."

cleaned_phrase, token_phrase = cleaner(phrase)
print("La phrase nettoyée : ", cleaned_phrase)
print("La phrase tokenizée : ", token_phrase)
# Out:
# La phrase nettoyée :   chat mange une souris  souris est mangée par  chat  souris que  chat mangée souris chat est  chat qui mange  souris
# La phrase tokenizée :  ['chat', 'mange', 'une', 'souris', 'souris', 'est', 'mangée', 'par', 'chat', 'souris', 'que', 'chat', 'mangée', 'souris', 'chat', 'est', 'chat', 'qui', 'mange', 'souris']

# %% [markdown]
# La même phrase avec les "stop_words en moins":

# %%
fr_stopwords = stopwords.words("french") # on met les stop words de nltk dans une liste
cleaned_phrase, token_phrase = cleaner(phrase, remove_stopword=fr_stopwords)
print("La phrase nettoyée : ", cleaned_phrase)
print("La phrase tokenizée : ", token_phrase)
# Out:
# La phrase nettoyée :  chat mange souris souris mangée chat souris chat mangée souris chat chat mange souris
# La phrase tokenizée :  ['chat', 'mange', 'souris', 'souris', 'mangée', 'chat', 'souris', 'chat', 'mangée', 'souris', 'chat', 'chat', 'mange', 'souris']

# %% [markdown]
# ### Exercice
#
# Utiliser la même fonction `cleaner` en utilisant cette fois la liste des stopwords proposée par Spacy

# %%
# Ecrire le code dans cette cellule

# %% [markdown]
# Nous allons maintenant répéter la fonction de nettoyage sur chacun des segments de l'entretien de Grazia Borrinin en utilisant le dataframe `gb`

# %%
fr_stopwords = list(nlp.Defaults.stop_words)#stopwords.words("french")

dict_token = {} #dictionnaire pour "conserver" la liste des tokens de chaque segment
dict_text = {} #dictionnaire pour "conserver" les segments nettoyés
for n, seg in enumerate(gb.id): # pour chaque segment dans la colonne gb.id
    row = gb.iloc[n] #on extrait lla ligne
    text = row['text']#on extrait le texte
    clean_text, split_text = cleaner(text, lower_case = True, remove_stopword=fr_stopwords)
    dict_token[seg]="|".join(split_text)
    dict_text[seg]= clean_text

gb["cleaned_text"] = gb.id.map(dict_text.get)
gb["tokens"] = gb.id.map(dict_token.get)

gb["tokens"]= gb.tokens.str.split("|")
gb_explode = gb[["id","bloc_id","speaker","tokens"]].explode("tokens")
gb_explode.tokens.value_counts()
# Out:
# tokens
# faire         87
# beaucoup      81
# vraiment      65
# choses        55
# chose         51
#               ..
# récolte        1
# données        1
# labo           1
# implémenté     1
# blablabla      1
# Name: count, Length: 1791, dtype: int64

# %%
gb_explode.loc[gb_explode.tokens=="c"]
gb.loc[gb.id == "seg_2"]
# Out:
#       id         start           end    speaker  \
# 1  seg_2  00:00:09,299  00:00:19,930  Speaker 1
#
#                                                 text  start_in_ms  end_in_ms  \
# 1  C'est un projet porté par à la fois Stéphanie ...        9.299      19.93
#
#   bloc_id                                          bloc_text    start_bloc  \
# 1  bloc_0  Je suis arrivé en post-doctorat au Muséum Nati...  00:00:01,820
#
#        end_bloc  start_bloc_ms  end_bloc_ms        partipat  nb_partipat  \
# 1  00:00:09,259           1.82        9.259  participatives          1.0
#
#                                         cleaned_text  \
# 1  projet porté fois stéphanie duvaille écologues...
#
#                                               tokens
# 1  [projet, porté, fois, stéphanie, duvaille, éco...

# %%
import numpy as np

# %%
token_freq = gb_explode.groupby(["speaker","tokens"]).agg(term_freq=("speaker","size")).reset_index()
size_seg = gb_explode.groupby(["speaker"]).agg(nb_tokens=("tokens","size")).reset_index()
nb_of_seg = gb_explode.speaker.nunique()
nb_seg_with_freq = gb_explode[["speaker","tokens"]].drop_duplicates().groupby("tokens").agg(nb_doc=("speaker","size")).reset_index()

df_tf = token_freq.merge(size_seg, on = ["speaker"], how = "left").merge(nb_seg_with_freq, on = ["tokens"], how = "left")
df_tf["tf"]= df_tf.term_freq/df_tf.nb_tokens
df_tf["idf"]= np.log((nb_of_seg+1)/df_tf.nb_doc)+1
df_tf["tfidf"]= df_tf.tf*df_tf.idf
df_tf.loc[df_tf.speaker == "Speaker 1"].sort_values(by="tfidf", ascending = False)
# Out:
#         speaker         tokens  term_freq  nb_tokens  nb_doc        tf  \
# 1622  Speaker 1                        13        573       2  0.022688
# 1740  Speaker 1          faire         11        573       2  0.019197
# 1649  Speaker 1           avez          9        573       2  0.015707
# 1698  Speaker 1           coup          6        573       1  0.010471
# 1792  Speaker 1      justement          8        573       2  0.013962
# ...         ...            ...        ...        ...     ...       ...
# 1931  Speaker 1        science          1        573       2  0.001745
# 1933  Speaker 1  scientifiques          1        573       2  0.001745
# 1912  Speaker 1        revenir          1        573       2  0.001745
# 1633  Speaker 1          année          1        573       2  0.001745
# 1634  Speaker 1           apac          1        573       2  0.001745
#
#            idf     tfidf
# 1622  1.405465  0.031887
# 1740  1.405465  0.026981
# 1649  1.405465  0.022075
# 1698  2.098612  0.021975
# 1792  1.405465  0.019623
# ...        ...       ...
# 1931  1.405465  0.002453
# 1933  1.405465  0.002453
# 1912  1.405465  0.002453
# 1633  1.405465  0.002453
# 1634  1.405465  0.002453
#
# [357 rows x 8 columns]

# %%
def compute_tfidf(data, group_by):
    token_freq = data.groupby([group_by,"tokens"]).agg(term_freq=(group_by,"size")).reset_index()
    size_seg = data.groupby([group_by]).agg(nb_tokens=("tokens","size")).reset_index()
    nb_of_seg = data.speaker.nunique()
    nb_seg_with_freq = data[[group_by,"tokens"]].drop_duplicates().groupby("tokens").agg(nb_doc=(group_by,"size")).reset_index()
    
    df_tf = token_freq.merge(size_seg, on = [group_by], how = "left").merge(nb_seg_with_freq, on = ["tokens"], how = "left")
    df_tf["tf"]= df_tf.term_freq/df_tf.nb_tokens
    df_tf["idf"]= np.log((nb_of_seg+1)/df_tf.nb_doc)+1
    df_tf["tfidf"]= df_tf.tf*df_tf.idf
    return df_tf

# %%
gb_explode
# Out:
#           id   bloc_id    speaker         tokens
# 0      seg_1    bloc_0  Speaker 1         arrivé
# 0      seg_1    bloc_0  Speaker 1  post-doctorat
# 0      seg_1    bloc_0  Speaker 1         muséum
# 0      seg_1    bloc_0  Speaker 1       national
# 0      seg_1    bloc_0  Speaker 1       historie
# ..       ...       ...        ...            ...
# 930  seg_931  bloc_109  Speaker 0        exister
# 931  seg_932  bloc_109  Speaker 0          fiche
# 932  seg_933  bloc_110  Speaker 1            bon
# 932  seg_933  bloc_110  Speaker 1        essayer
# 933  seg_934  bloc_110  Speaker 1            cas
#
# [5230 rows x 4 columns]

# %%
df = compute_tfidf(data=gb_explode, group_by="bloc_id")
#dict_tfidf
df["id_bloc"] = df.bloc_id.str.replace("bloc_","").astype(int)
df = df.merge(gb_explode[["bloc_id", "speaker"]].drop_duplicates(), on = ["bloc_id"], how ="left")
df = df.loc[df.speaker == "Speaker 0"].sort_values("id_bloc", ascending=True)

for bloc in df.id_bloc.unique():
    df_bloc = df.loc[df.id_bloc == bloc].sort_values("tfidf", ascending=False)
    specific_term = [x for x in df_bloc.tokens.head(5)]
    print(f"Les 5 termes les plus spécifique du bloc {bloc} sont : ", specific_term)
# Out:
# Les 5 termes les plus spécifique du bloc 1 sont :  ['citizen', 'science']
# Les 5 termes les plus spécifique du bloc 3 sont :  ['recherche', 'direction', 'peut-être', 'est-']
# Les 5 termes les plus spécifique du bloc 5 sont :  ['allez', 'volontiers', 'choix', 'but', 'esprit']
# Les 5 termes les plus spécifique du bloc 7 sont :  ['cadre-', 'ensemble', '']
# Les 5 termes les plus spécifique du bloc 9 sont :  ['normaux']
# Les 5 termes les plus spécifique du bloc 11 sont :  ['']
# Les 5 termes les plus spécifique du bloc 13 sont :  ['voulez', 'aimeriez', 'vieille', 'passionnant', 'condominium']
# Les 5 termes les plus spécifique du bloc 15 sont :  ['pâques', 'français']
# Les 5 termes les plus spécifique du bloc 17 sont :  ['consortiums', 'oui']
# Les 5 termes les plus spécifique du bloc 19 sont :  ['citoyens', 'efforts', 'aimeriez', 'superposent', 'changement']
# Les 5 termes les plus spécifique du bloc 21 sont :  ['maison', 'physique', 'religion', 'lire', 'pouvons']
# Les 5 termes les plus spécifique du bloc 23 sont :  ['soins', 'décident', 'médecins', 'voulaient', 'primaire']
# Les 5 termes les plus spécifique du bloc 25 sont :  ['care', 'primary', 'aucune', 'faim', 'health']
# Les 5 termes les plus spécifique du bloc 27 sont :  ['novembre', 'allé', 'galère', 'dérangé', 'pleut']
# Les 5 termes les plus spécifique du bloc 29 sont :  ['problématique', 'endroit', 'motivés', 'exécution', 'mai']
# Les 5 termes les plus spécifique du bloc 31 sont :  ['sofa-', 'attends', 'pieds', 'écrire', 'sympa']
# Les 5 termes les plus spécifique du bloc 33 sont :  ['gestion', 'faune', 'éléphants', 'working', 'tué']
# Les 5 termes les plus spécifique du bloc 35 sont :  ['commission', 'and', 'qashqai', 'thème', 'yémen']
# Les 5 termes les plus spécifique du bloc 37 sont :  ['disiez', 'urban']
# Les 5 termes les plus spécifique du bloc 39 sont :  ['congress', 'world', 'sydney', 'parks', 'stream']
# Les 5 termes les plus spécifique du bloc 41 sont :  ['pouf', 'mobiles', 'tagui', 'dana', 'marcus']
# Les 5 termes les plus spécifique du bloc 43 sont :  ['raconter', 'parallèle', 'fond', 'faudra', 'consumers']
# Les 5 termes les plus spécifique du bloc 45 sont :  ['oui']
# Les 5 termes les plus spécifique du bloc 47 sont :  ['différences', 'amérique', 'business', 'augmenté', 'revendication']
# Les 5 termes les plus spécifique du bloc 49 sont :  ['mange', 'membres', 'niveau', 'organisations', 'travaillaient']
# Les 5 termes les plus spécifique du bloc 51 sont :  ['interviewé', 'giorgi', 'carigno']
# Les 5 termes les plus spécifique du bloc 53 sont :  ['femmes', 'georgie', 'marcus', 'vicky', 'program']
# Les 5 termes les plus spécifique du bloc 55 sont :  ['peuple', 'conditionnalité', 'sang', 'entrer', 'juif']
# Les 5 termes les plus spécifique du bloc 57 sont :  ['saints', 'oui']
# Les 5 termes les plus spécifique du bloc 59 sont :  ['pristine', 'coule', 'dynamicité', 'viens', 'valeur']
# Les 5 termes les plus spécifique du bloc 61 sont :  ['conservées', 'apaq', 'oecm', 'définition', 'démontre']
# Les 5 termes les plus spécifique du bloc 63 sont :  ['h', 'rendez-vous', 'accord', 'bien', 'oui']
# Les 5 termes les plus spécifique du bloc 65 sont :  ['non-arrogance', 'scientifiques', 'dirais', 'non-scientifiques', 'monde']
# Les 5 termes les plus spécifique du bloc 67 sont :  ['tirer', 'construction', 'articles', 'connaissance', 'arrivaient']
# Les 5 termes les plus spécifique du bloc 69 sont :  ['réel', 'échecs', 'confectionnées', 'gaspillage', 'incontournable']
# Les 5 termes les plus spécifique du bloc 71 sont :  ['bien-être', 'cultiver', 'contradictions', 'créent', 'mine']
# Les 5 termes les plus spécifique du bloc 73 sont :  ['vaincre', 'fatiguant', 'beau', 'magnifique', 'groupe']
# Les 5 termes les plus spécifique du bloc 75 sont :  ['voulait', 'cause', 'arrive', 'participation', 'oui']
# Les 5 termes les plus spécifique du bloc 77 sont :  ['bandits', 'démocratie', 'agitent', 'fantômes', 'informés']
# Les 5 termes les plus spécifique du bloc 79 sont :  ['individus', 'sauvegardes', 'terribles', 'professionnelle', 'budgets']
# Les 5 termes les plus spécifique du bloc 81 sont :  ['olivier', 'répondu', 'cherchais', 'jiao', 'intervieweux']
# Les 5 termes les plus spécifique du bloc 83 sont :  ['changer', 'imagine', 'hypersensibilité', 'situation', 'particulière']
# Les 5 termes les plus spécifique du bloc 85 sont :  ['france', 'cas', 'beaucoup']
# Les 5 termes les plus spécifique du bloc 87 sont :  ['accrue', 'sensibilité']
# Les 5 termes les plus spécifique du bloc 89 sont :  ['bâtit', 'apparemment', 'affectés', 'action', 'soient']
# Les 5 termes les plus spécifique du bloc 91 sont :  ['envoyer', 'guide', 'renforcer', 'développé', 'gestionnaires']
# Les 5 termes les plus spécifique du bloc 93 sont :  ['menaces', 'territoire', 'conscience', 'phénomènes', 'demande']
# Les 5 termes les plus spécifique du bloc 95 sont :  ['réseau', 'niveaux', 'eaux', 'propos', 'prises']
# Les 5 termes les plus spécifique du bloc 97 sont :  ['comité', 'agence', 'fini', 'haut', 'nationaux']
# Les 5 termes les plus spécifique du bloc 99 sont :  ['dépense', 'désorganiser', 'organiser', 'argent', 'faut']
# Les 5 termes les plus spécifique du bloc 101 sont :  ['cbd', 'millions', 'plans', 'démontrées', 'implémentation']
# Les 5 termes les plus spécifique du bloc 103 sont :  ['reinventer', 'discours', 'chaude', 'bénéfices', 'permettre']
# Les 5 termes les plus spécifique du bloc 105 sont :  ['intéresserait', 'dures', 'aller', 'poser', 'savoir']
# Les 5 termes les plus spécifique du bloc 107 sont :  ['positions', 'élèves', 'élever', 'manque', 'défavorisées']
# Les 5 termes les plus spécifique du bloc 109 sont :  ['cherchons', 'responsabilités', 'identité', 'accru', 'arbre-']

# %%
df.sort_values("id_bloc", ascending=True)
# Out:
#        bloc_id      tokens  term_freq  nb_tokens  nb_doc        tf       idf  \
# 23      bloc_1     citizen          1          2       2  0.500000  1.405465
# 24      bloc_1     science          1          2       4  0.500000  0.712318
# 1363    bloc_3        est-          1          4      19  0.250000 -0.845827
# 1362    bloc_3   direction          1          4       4  0.250000  0.712318
# 1364    bloc_3   peut-être          1          4      13  0.250000 -0.466337
# ...        ...         ...        ...        ...     ...       ...       ...
# 341   bloc_109    sérieuse          1         77       1  0.012987  2.098612
# 340   bloc_109  souffrance          1         77       2  0.012987  1.405465
# 339   bloc_109    sociales          1         77       2  0.012987  1.405465
# 338   bloc_109        sens          2         77       3  0.025974  1.000000
# 336   bloc_109      réussi          1         77       4  0.012987  0.712318
#
#          tfidf  id_bloc    speaker
# 23    0.702733        1  Speaker 0
# 24    0.356159        1  Speaker 0
# 1363 -0.211457        3  Speaker 0
# 1362  0.178079        3  Speaker 0
# 1364 -0.116584        3  Speaker 0
# ...        ...      ...        ...
# 341   0.027255      109  Speaker 0
# 340   0.018253      109  Speaker 0
# 339   0.018253      109  Speaker 0
# 338   0.025974      109  Speaker 0
# 336   0.009251      109  Speaker 0
#
# [3309 rows x 10 columns]

# %% [markdown]
# ## TF-IDF avec scikit learn

# %%
# importer le vectoriseur TfidfVectorizer de Scikit-Learn.  
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Chargement du modèle français de SpaCy
nlp = spacy.load('fr_core_news_md')  # ou 'en_core_web_sm' pour l'anglais
# Récupération et extension des stopwords par défaut de SpaCy
spacy_stopwords = set(nlp.Defaults.stop_words)



# Application de la lemmatisation et de la suppression des stopwords sur chaque document

# %%
# Fonction pour lemmatiser le texte et retirer les stopwords
def lemmatize_and_remove_stopwords(text, nlp, stopwords, lemmatiser = True):
    doc = nlp(text)
    if lemmatiser == True:
        cleaned_text = " ".join([token.lemma_ for token in doc if token.text.lower() not in stopwords and not token.is_punct])
    else:
        cleaned_text = " ".join([str(token) for token in doc if token.text.lower() not in stopwords and not token.is_punct])
    return cleaned_text

# %%
print(list_bloc_text[0]["bloc_text"])
print(lemmatize_and_remove_stopwords(list_bloc_text[0]["bloc_text"], nlp, spacy_stopwords))
# Out:
# Donc je vais vous présenter un peu, redire un peu pourquoi on se rencontre et puis on intègre pas l'entretien. Donc moi je suis Aymeric et j'ai été recruté en post-doctorat pour travailler sur la question des observatoires participatifs.
# présenter redire rencontre intégrer entretien Aymeric être recruter post-doctorat travailler question observatoire participatif

# %%
tous_documents = []
for bloc in list_bloc_text:
    lemmatized_an_cleaned_text = lemmatize_and_remove_stopwords(bloc["bloc_text"], nlp, spacy_stopwords, lemmatiser = True)
    tous_documents.append(lemmatized_an_cleaned_text)

vectoriseur = TfidfVectorizer(max_df=.65, min_df=1, use_idf=True)
documents_transformes = vectoriseur.fit_transform(tous_documents)

# %%
documents_transformes_tableau = documents_transformes.toarray()
len(documents_transformes_tableau)
# Out:
# 156

# %%
i = -1
for compteur, document in enumerate(documents_transformes_tableau):
    i+=1
    #print("#####\n",document)
    # construire un objet de la classe DataFrame
    tf_idf_tuples = list(zip(vectoriseur.get_feature_names_out(), document))
    df0 = pd.DataFrame.from_records(tf_idf_tuples, columns=['terme', 'pointage']).sort_values(by='pointage', ascending=False).reset_index(drop=True)
    df0 = df0.loc[df0.pointage > 0]
    df0['bloc_id'] = str(compteur)
    if i == 0:
        df = df0.copy()
    else:
        df = pd.concat([df, df0])

for bloc in df.bloc_id.unique():
    df_bloc = df.loc[df.bloc_id == bloc].sort_values("pointage", ascending=False)
    specific_term = [x for x in df_bloc.terme.head(5)]
    print(f"Les 5 termes les plus spécifique du bloc {bloc} sont : ", specific_term)
# Out:
# Les 5 termes les plus spécifique du bloc 0 sont :  ['recruter', 'aymeric', 'observatoire', 'post', 'présenter']
# Les 5 termes les plus spécifique du bloc 1 sont :  ['formation', 'doctorat', 'être']
# Les 5 termes les plus spécifique du bloc 2 sont :  ['sociologie', 'former', 'sociologu', 'thèse', 'accord']
# Les 5 termes les plus spécifique du bloc 3 sont :  ['sociologie', 'environnement']
# Les 5 termes les plus spécifique du bloc 4 sont :  ['riverain', 'environnemental', 'engager', 'conflit', 'travailler']
# Les 5 termes les plus spécifique du bloc 5 sont :  ['riverain']
# Les 5 termes les plus spécifique du bloc 6 sont :  ['riverain', 'pollution', 'engager', 'problème']
# Les 5 termes les plus spécifique du bloc 7 sont :  ['accord']
# Les 5 termes les plus spécifique du bloc 8 sont :  ['autour', 'hypersensibilité', 'marseille', 'controversée', 'chimique']
# Les 5 termes les plus spécifique du bloc 9 sont :  ['ok']
# Les 5 termes les plus spécifique du bloc 10 sont :  ['pratique', 'regard', 'proposer', 'parcours', 'commencer']
# Les 5 termes les plus spécifique du bloc 11 sont :  ['savoir', 'travailler', 'barrage', 'vraiment', 'inuit']
# Les 5 termes les plus spécifique du bloc 12 sont :  ['vulgarisation', 'coproduction', 'petit', 'parler', 'savoir']
# Les 5 termes les plus spécifique du bloc 13 sont :  ['résultat', 'coproduction', 'savoir', 'marche', 'scientifique']
# Les 5 termes les plus spécifique du bloc 14 sont :  ['contexte', 'année', 'indio', 'historique', '70']
# Les 5 termes les plus spécifique du bloc 15 sont :  ['article', 'valoir', 'référence', 'donner', 'écrire']
# Les 5 termes les plus spécifique du bloc 16 sont :  ['niveau', 'population', 'droit', 'mouvement', 'exemple']
# Les 5 termes les plus spécifique du bloc 17 sont :  ['droit', 'comprendre', 'mouvement', 'façon', 'savoir']
# Les 5 termes les plus spécifique du bloc 18 sont :  ['écrasement', 'politique', 'histoire', 'lier', 'france']
# Les 5 termes les plus spécifique du bloc 19 sont :  ['gestion', 'parc', 'origine', 'venir', 'savoir']
# Les 5 termes les plus spécifique du bloc 20 sont :  ['curiosité', 'vous', 'thèse', 'avoir', 'coup']
# Les 5 termes les plus spécifique du bloc 21 sont :  ['thèse', 'technologie', 'gourand', 'leroy', 'cresswell']
# Les 5 termes les plus spécifique du bloc 22 sont :  ['claude', 'mentionner', 'resituer', 'ouvrage', 'lévi']
# Les 5 termes les plus spécifique du bloc 23 sont :  ['strauss', 'lévi', 'vraiment', 'savoir', 'pensée']
# Les 5 termes les plus spécifique du bloc 24 sont :  ['confrontation', 'moment', 'équilibrer', 'interrogation', 'éviter']
# Les 5 termes les plus spécifique du bloc 25 sont :  ['nécessairement', 'interdisciplinaire', 'principe', 'beaucoup', 'intéresser']
# Les 5 termes les plus spécifique du bloc 26 sont :  ['concrètement', 'intégration', 'panel', 'ipb', 'présenter']
# Les 5 termes les plus spécifique du bloc 27 sont :  ['construction', 'interdisciplinarité', 'partie', 'mouvement', 'bon']
# Les 5 termes les plus spécifique du bloc 28 sont :  ['expertise', 'ipbes', 'travail', 'coup']
# Les 5 termes les plus spécifique du bloc 29 sont :  ['faire', 'publier', 'littérature', 'citable', 'permettre']
# Les 5 termes les plus spécifique du bloc 30 sont :  ['amont', 'supposer', 'retrouver', 'intégrer', 'travail']
# Les 5 termes les plus spécifique du bloc 31 sont :  ['insister', 'résoudre', 'évoluer', 'beaucoup', 'ce']
# Les 5 termes les plus spécifique du bloc 32 sont :  ['renvoyer', 'synonyme', 'ce', 'savoir', 'connaissance']
# Les 5 termes les plus spécifique du bloc 33 sont :  ['connaissance', 'science', 'ce', 'impliquer', 'détermination']
# Les 5 termes les plus spécifique du bloc 34 sont :  ['impression', 'connaissance', 'scientifique', 'exemple', 'local']
# Les 5 termes les plus spécifique du bloc 35 sont :  ['raison', 'doute', 'avoir', 'oui']
# Les 5 termes les plus spécifique du bloc 36 sont :  ['savoir']
# Les 5 termes les plus spécifique du bloc 37 sont :  ['raison', 'doute', 'avoir']
# Les 5 termes les plus spécifique du bloc 38 sont :  ['implication', 'ce']
# Les 5 termes les plus spécifique du bloc 39 sont :  ['connaissance', 'participatif', 'savoir', 'knowledge', 'méthode']
# Les 5 termes les plus spécifique du bloc 40 sont :  ['non', 'équilibre', 'symétrie', 'canon', 'récolte']
# Les 5 termes les plus spécifique du bloc 41 sont :  ['précédent', 'entendre', 'génération', 'chose', 'immémorial']
# Les 5 termes les plus spécifique du bloc 42 sont :  ['étonnant', 'em', 'récemment', 'roger', 'ancien']
# Les 5 termes les plus spécifique du bloc 43 sont :  ['chose', 'oui']
# Les 5 termes les plus spécifique du bloc 44 sont :  ['muséum', 'chose']
# Les 5 termes les plus spécifique du bloc 45 sont :  ['heure', 'écrire']
# Les 5 termes les plus spécifique du bloc 46 sont :  ['confronter', 'précisément', 'écrir', 'être', 'local']
# Les 5 termes les plus spécifique du bloc 47 sont :  ['prêter', 'stylo', 'truc', 'roger', 'coin']
# Les 5 termes les plus spécifique du bloc 48 sont :  ['intéressant', 'muséum', 'coup', 'sensibilité', 'sembler']
# Les 5 termes les plus spécifique du bloc 49 sont :  ['équipe', 'époque', 'diriger', 'lier', 'droit']
# Les 5 termes les plus spécifique du bloc 50 sont :  ['chronologie', 'citoyen', 'reconnaissance', 'entier', 'inuite']
# Les 5 termes les plus spécifique du bloc 51 sont :  ['canadien', 'oui', 'individu', 'tardif', 'anglophone']
# Les 5 termes les plus spécifique du bloc 52 sont :  ['vraiment', 'différence', 'ce']
# Les 5 termes les plus spécifique du bloc 53 sont :  ['rémi', 'droit', 'falloir', 'mouvement', 'croire']
# Les 5 termes les plus spécifique du bloc 54 sont :  ['connaître', 'savoir', 'foyer', 'prise', 'courant']
# Les 5 termes les plus spécifique du bloc 55 sont :  ['occupant', 'désoccuper', 'bonjour']
# Les 5 termes les plus spécifique du bloc 56 sont :  ['descendre', 'oui']
# Les 5 termes les plus spécifique du bloc 57 sont :  ['désolé', 'descendre', 'oui']
# Les 5 termes les plus spécifique du bloc 58 sont :  ['porte']
# Les 5 termes les plus spécifique du bloc 59 sont :  ['demander', 'oui']
# Les 5 termes les plus spécifique du bloc 60 sont :  ['gaz', 'rendez', 'foyer', 'vous']
# Les 5 termes les plus spécifique du bloc 61 sont :  ['chambers', 'sortir', 'couper', 'évoluer', 'position']
# Les 5 termes les plus spécifique du bloc 62 sont :  ['ipes', 'sommet', 'semaine', 'dernier']
# Les 5 termes les plus spécifique du bloc 63 sont :  ['validation', 'total', 'respectueux', 'pêcherie', 'finalement']
# Les 5 termes les plus spécifique du bloc 64 sont :  ['action', 'hall', 'bud', 'question', 'quelque']
# Les 5 termes les plus spécifique du bloc 65 sont :  ['nom', 'mettez', 'rien', 'moi', 'regarder']
# Les 5 termes les plus spécifique du bloc 66 sont :  ['dé', 'savoir']
# Les 5 termes les plus spécifique du bloc 67 sont :  ['rappeler', 'cas']
# Les 5 termes les plus spécifique du bloc 68 sont :  ['paolo', 'frere', 'inscrire', 'approche', 'ce']
# Les 5 termes les plus spécifique du bloc 69 sont :  ['objet', 'smithsonian', 'approche', 'musée', 'aller']
# Les 5 termes les plus spécifique du bloc 70 sont :  ['dialoguer', 'emprise', 'élément', 'interaction', 'cartographie']
# Les 5 termes les plus spécifique du bloc 71 sont :  ['frappant', 'allée', 'bande', 'mine', 'rencontrer']
# Les 5 termes les plus spécifique du bloc 72 sont :  ['calon', 'vouloir']
# Les 5 termes les plus spécifique du bloc 73 sont :  ['évidemment', 'bon', 'liberté', 'liberteur', 'situationniste']
# Les 5 termes les plus spécifique du bloc 74 sont :  ['use', 'land', 'beaucoup', 'borini', 'paloc']
# Les 5 termes les plus spécifique du bloc 76 sont :  ['communautaire', 'groupe', 'autochtones', 'français', 'aire']
# Les 5 termes les plus spécifique du bloc 77 sont :  ['connaître', 'ucn', 'personnel', 'attendre', 'carigno']
# Les 5 termes les plus spécifique du bloc 78 sont :  ['accord']
# Les 5 termes les plus spécifique du bloc 79 sont :  ['site', 'part', 'haut', 'travailler', 'servir']
# Les 5 termes les plus spécifique du bloc 80 sont :  ['uicn', '90', 'travers', 'oui', 'année']
# Les 5 termes les plus spécifique du bloc 81 sont :  ['minoritaire', 'actuel', 'rappeler', '90', 'nom']
# Les 5 termes les plus spécifique du bloc 82 sont :  ['accord', 'oui']
# Les 5 termes les plus spécifique du bloc 83 sont :  ['mooc', 'mouvement', 'raconter', 'faire', 'péter']
# Les 5 termes les plus spécifique du bloc 84 sont :  ['accord']
# Les 5 termes les plus spécifique du bloc 85 sont :  ['gagner', 'ong', 'carreño', 'actif', 'actuellement']
# Les 5 termes les plus spécifique du bloc 86 sont :  ['non']
# Les 5 termes les plus spécifique du bloc 87 sont :  ['hum', 'question', 'droit', 'terrorisme', 'abbé']
# Les 5 termes les plus spécifique du bloc 88 sont :  ['justement', 'onu', 'organisation', 'rôle', 'environnement']
# Les 5 termes les plus spécifique du bloc 89 sont :  ['travers', 'banque', 'réglementation', 'mondial', 'bien']
# Les 5 termes les plus spécifique du bloc 90 sont :  ['différence', 'coup']
# Les 5 termes les plus spécifique du bloc 91 sont :  ['relation', 'gouvernement', 'difficulté', 'signer', 'avantage']
# Les 5 termes les plus spécifique du bloc 92 sont :  ['sommet', 'semaine', 'dernier']
# Les 5 termes les plus spécifique du bloc 93 sont :  ['politique']
# Les 5 termes les plus spécifique du bloc 94 sont :  ['bogota', 'ipb', 'sommet', 'semaine', 'dernier']
# Les 5 termes les plus spécifique du bloc 95 sont :  ['medellín', 'oui', 'lundi', 'revien', 'bogota']
# Les 5 termes les plus spécifique du bloc 96 sont :  ['politique', 'fois', 'effet', 'construire', 'scientifique']
# Les 5 termes les plus spécifique du bloc 97 sont :  ['question']
# Les 5 termes les plus spécifique du bloc 98 sont :  ['scientifique']
# Les 5 termes les plus spécifique du bloc 100 sont :  ['intégration', 'prise', 'savoir', 'compte', 'local']
# Les 5 termes les plus spécifique du bloc 101 sont :  ['local']
# Les 5 termes les plus spécifique du bloc 102 sont :  ['effet', 'ce', 'décrire', 'vous', 'changement']
# Les 5 termes les plus spécifique du bloc 103 sont :  ['discussion', 'hier', 'choix', 'mail', 'plein']
# Les 5 termes les plus spécifique du bloc 104 sont :  ['changer', 'obligation', 'légal', 'devenir', 'justement']
# Les 5 termes les plus spécifique du bloc 105 sont :  ['asie', 'europe', 'gouvernement', 'mot', 'décideur']
# Les 5 termes les plus spécifique du bloc 106 sont :  ['sentir', 'heure', 'disparaître', 'ipbes', 'dire']
# Les 5 termes les plus spécifique du bloc 107 sont :  ['activiste', 'dépendre', 'expert', 'principe', 'difficile']
# Les 5 termes les plus spécifique du bloc 108 sont :  ['faire', 'europe', 'penser', 'parler', 'dire']
# Les 5 termes les plus spécifique du bloc 109 sont :  ['excusez', 'moi']
# Les 5 termes les plus spécifique du bloc 110 sont :  ['folklore', 'europe', 'problème', 'etc', 'justement']
# Les 5 termes les plus spécifique du bloc 111 sont :  ['autrefois', 'lapon', 'oui', 'là', 'dire']
# Les 5 termes les plus spécifique du bloc 112 sont :  ['traditionnel']
# Les 5 termes les plus spécifique du bloc 113 sont :  ['apercevoir', 'culture', 'vue', 'point', 'désespéré']
# Les 5 termes les plus spécifique du bloc 114 sont :  ['question', 'identifier', 'chercheur', 'acteur', 'autour']
# Les 5 termes les plus spécifique du bloc 115 sont :  ['connaître']
# Les 5 termes les plus spécifique du bloc 116 sont :  ['connaître']
# Les 5 termes les plus spécifique du bloc 117 sont :  ['alejandro', 'armando', 'nakashima', 'fikret', 'douglas']
# Les 5 termes les plus spécifique du bloc 118 sont :  ['cacher']
# Les 5 termes les plus spécifique du bloc 119 sont :  ['mari', 'oui']
# Les 5 termes les plus spécifique du bloc 120 sont :  ['lynx', 'consister', 'programme', 'regarder', 'ailleurs']
# Les 5 termes les plus spécifique du bloc 121 sont :  ['système', 'école', 'connaissance', 'savoir', 'tradition']
# Les 5 termes les plus spécifique du bloc 122 sont :  ['entretien', 'douglas', 'penser', 'justement', 'faire']
# Les 5 termes les plus spécifique du bloc 123 sont :  ['écouter', 'demander', 'cas', 'bien']
# Les 5 termes les plus spécifique du bloc 124 sont :  ['toronto', 'été', 'pareil', 'ce']
# Les 5 termes les plus spécifique du bloc 126 sont :  ['toronto', 'rencontrer', 'profiter', 'congrès', 'indiquer']
# Les 5 termes les plus spécifique du bloc 127 sont :  ['doug', 'savoir', 'mari', 'voir', 'retraite']
# Les 5 termes les plus spécifique du bloc 128 sont :  ['étudiant', 'canadien', 'montréal', 'parler', 'exemple']
# Les 5 termes les plus spécifique du bloc 129 sont :  ['disai', 'écrit', 'avancé', 'fite', 'harvey']
# Les 5 termes les plus spécifique du bloc 130 sont :  ['malade', 'heure', 'étudiant', 'canadien', 'parler']
# Les 5 termes les plus spécifique du bloc 131 sont :  ['lamour', 'francophone', 'musée', 'milieu', 'savoir']
# Les 5 termes les plus spécifique du bloc 132 sont :  ['incorporer', 'acceptable', 'mieux', 'conserve', 'idée']
# Les 5 termes les plus spécifique du bloc 133 sont :  ['ottawa', 'parc', 'dave', 'baser', 'nouveau']
# Les 5 termes les plus spécifique du bloc 134 sont :  ['muséum', 'france', 'avoir', 'ce']
# Les 5 termes les plus spécifique du bloc 135 sont :  ['frédéric', 'interviewer', 'clous', 'non', 'avoir']
# Les 5 termes les plus spécifique du bloc 137 sont :  ['donnée', 'base']
# Les 5 termes les plus spécifique du bloc 138 sont :  ['comité', 'partie']
# Les 5 termes les plus spécifique du bloc 139 sont :  ['diriger', 'interviewer', 'pouvoir', 'oui']
# Les 5 termes les plus spécifique du bloc 140 sont :  ['envisageable']
# Les 5 termes les plus spécifique du bloc 141 sont :  ['paysage', 'séminaire', 'humain', 'notion', 'site']
# Les 5 termes les plus spécifique du bloc 142 sont :  ['océanien', 'ère', 'frédéric', 'clous', 'coup']
# Les 5 termes les plus spécifique du bloc 143 sont :  ['approche', 'vouloir', 'frédérique', 'diron', 'nous']
# Les 5 termes les plus spécifique du bloc 144 sont :  ['collaboratif', 'croire']
# Les 5 termes les plus spécifique du bloc 145 sont :  ['pratique', 'savoir', 'cas', 'peut', 'scientifique']
# Les 5 termes les plus spécifique du bloc 146 sont :  ['pratique', 'savoir', 'différence', 'accord', 'coup']
# Les 5 termes les plus spécifique du bloc 147 sont :  ['pratique', 'accent', 'entendre', 'savoir', 'mettre']
# Les 5 termes les plus spécifique du bloc 148 sont :  ['croyance', 'durkheim', 'souvenir']
# Les 5 termes les plus spécifique du bloc 149 sont :  ['oui']
# Les 5 termes les plus spécifique du bloc 150 sont :  ['chose', 'faire', 'machinalement', 'dimension', 'habitude']
# Les 5 termes les plus spécifique du bloc 151 sont :  ['terrain', 'occuper', 'croire', 'mot', 'écologie']
# Les 5 termes les plus spécifique du bloc 152 sont :  ['11h25', 'rendez', 'vous', 'croire', 'avoir']
# Les 5 termes les plus spécifique du bloc 153 sont :  ['agroparistech', 'aller', 'doctorant', 'finir', 'temps']
# Les 5 termes les plus spécifique du bloc 154 sont :  ['vouloir', 'mot', 'dernier', 'avoir', 'ce']
# Les 5 termes les plus spécifique du bloc 155 sont :  ['article', 'trouvable', 'volontier', 'whistle', 'gate']
