# %%
import pydub
import ipywidgets as widgets
from IPython.display import Audio, display #pour écouter les extraits audio avec un notebook jupyter

# %%
import time
import csv
import datetime
import os.path

# %%
path_itw = "../records/grazia_borrini_07-06-18_part-1.MP3"

original_trancript_path = "../records/2026-01-09_itw_borrini.csv"
cleaned_trancript_path = "../records/2026-01-09_itw_borrini_cleaned.csv"

# %%
itw = pydub.AudioSegment.from_mp3("../records/sample.mp3")

# %%
csvfile = open(original_trancript_path, newline='')
csv_reader = csv.DictReader(csvfile)
rows = list(csv_reader)

with open(original_trancript_path, newline = '') as csv1:
    reader = csv.DictReader(csv1)
    with open(cleaned_trancript_path, newline = '') as csv2:
        reader2 = csv.DictReader(csv2)
        for n, row in enumerate(reader2):
            if row["cleaned_text"] is None
# Out:
# " de générer ça. Parfois je pense que j'ai des opinions un peu arriérées, car je crois"

# %%
for row in reader:
    #print(row['start_in_ms'], row['end_in_ms'])
    extract = itw_b[float(row['start_in_ms'])*1000:float(row['end_in_ms'])*1000]
    button = widgets.Button(
        description='Click me',
        disabled=False,
        button_style='', # 'success', 'info', 'warning', 'danger' or ''
        tooltip='Click me',
        icon='check' # (FontAwesome names without the `fa-` prefix)
        )
    display(button)
    button.on_click(foo)

# %%
button = widgets.Button(description="Click Me to Start!")
output = widgets.Output()

i = 0





def on_button_clicked(b):
    global i
    with output:
        button.description = "Next!"
        extract = itw[float(rows[i]['start_in_ms'])*1000:float(rows[i]['end_in_ms'])*1000]
        display(extract)
        new_speaker = widgets.Text(
                        placeholder='Speaker name',
                        description='Speaker:',
                        disabled=False   
                    )
        new_text = widgets.Textarea(
            value=rows[i]['text'].strip(),
            placeholder='Type something',
            description='String:',
            disabled=False,
            layout=widgets.Layout(width='50%', height='80px')
            )
        display(new_speaker)
        display(new_text)
        if os.path.exists("../records/2026-01-09_itw_borrini_cleaned.csv"):
            with open("../records/2026-01-09_itw_borrini_cleaned.csv" , 'a', newline='') as csvfile:
                fieldnames = ['start', 'end','cleaned_speaker', 'text','cleaned_text', 'start_in_ms','end_in_ms']
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writerow({'start': rows[i]["start"],
                                 'end': rows[i]["end"],
                                 'cleaned_speaker':new_speaker.value,
                                 'text':rows[i]['text'].strip(),
                                 'cleaned_text' : new_text.value,
                                 'start_in_ms':rows[i]['start_in_ms'],
                                 'end_in_ms':rows[i]['end_in_ms']})
        else:
            with open("../records/2026-01-09_itw_borrini_cleaned.csv" , 'w', newline='') as csvfile:
                fieldnames = ['start', 'end','cleaned_speaker', 'text','cleaned_text', 'start_in_ms','end_in_ms']
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerow({'start': rows[i]["start"], 
                                 'end': rows[i]["end"], 
                                 'cleaned_speaker':new_speaker.value, 
                                 'text':rows[i]['text'].strip(), 
                                 'cleaned_text' : new_text.value, 
                                 'start_in_ms':rows[i]['start_in_ms'], 
                                 'end_in_ms':rows[i]['end_in_ms']})
            
        i+=1


display(button, output)

button.on_click(on_button_clicked)
# Out:
# Button(description='Click Me to Start!', style=ButtonStyle())
# Output()
